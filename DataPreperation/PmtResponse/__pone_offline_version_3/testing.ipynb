# %%
file_path = "/home/kbas/scratch/String340MC_pone_offline_version3/Muon_PMT_Response/muon_cls_000.i3.gz"

# %%
from icecube import dataio
from icecube import LeptonInjector

i3file = dataio.I3File(file_path)

first_frame = None
first_frame_index = None

def is_triggered(value):
    if hasattr(value, 'value'):
        value = value.value
    return bool(value)

frame_index = 0
while i3file.more():
    frame = i3file.pop_frame()
    if 'triggered_340_string' in frame and is_triggered(frame['triggered_340_string']):
        first_frame = frame
        first_frame_index = frame_index
        break
    frame_index += 1

i3file.close()

if first_frame is None:
    raise RuntimeError('No frame found with triggered_340_string == 1')

print(f'Found triggered_340_string == 1 at frame index {first_frame_index}')

first_frame

# %%
keys_to_print = [
    'trigger_time_340_string',
    'triggered_340_string',
    'trigger_time_160_string',
    'trigger_time_102_string',
    'PMT_Response_nonoise_160_String',
    'PMT_Response_nonoise_102_String',
    'PMT_Response_340_String',
    'PMT_Response_nonoise_340_String',
    'PMT_Response_160_String',
    'PMT_Response_102_String',
    'Noise_K40_340_String',
    'Noise_K40_160_String',
    'Noise_K40_102_String',
    'Noise_Dark_340_String',
    'Noise_Dark_160_String',
    'Noise_Dark_102_String',
    'MMCTrackList',
    'I3Photons',
    'triggered_102_string',
    'I3MCTree_postprop',
    'I3MCTree_RNGState',
    'I3MCTree',
    'triggered_160_string',
    'I3EventHeader',
    'EventProperties',
    'Accepted_PulseMap_340String',
]

for key in sorted(keys_to_print):
    print(f'\n========== {key} ==========')
    if key in first_frame:
        print(first_frame[key])
    else:
        print(f'MISSING KEY: {key}')
# Out:
# ========== Accepted_PulseMap_340String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== EventProperties ==========
# [ BasicEventProperties
#          TotalEnergy : 51860.9
#               Zenith : 1.59773
#              Azimuth : 4.6631
#          FinalStateX : 0.00928052
#          FinalStateY : 0.303531
#           FinalType1 : MuMinus
#           FinalType2 : Hadrons
#          InitialType : NuMu
#                    X : 253.527
#                    Y : 977.093
#                    Z : -925.668
#     TotalColumnDepth : 2.55922e+06
#               Radius : 1009.45
#      ImpactParameter : 973.788
# ]
#
# ========== I3EventHeader ==========
# [ I3EventHeader:
#         StartTime: 1905-06-04 18:35:44.000,000,000,0 UTC
#          EndTime : 1905-06-04 18:35:44.000,000,000,0 UTC
#            RunID : 0
#         SubrunID : 4294967295
#          EventID : 3
#       SubEventID : 0
#   SubEventStream :
# ]
#
# ========== I3MCTree ==========
# [I3MCTree:
#   73 NuMu (253.527m, 977.093m, -925.668m) (91.5431deg, 267.176deg) 0ns 51860.9GeV 0m Primary
#     67 MuMinus (253.527m, 977.093m, -925.668m) (91.5212deg, 267.176deg) 0ns 36119.5GeV nanm MCTrack
#     70 Hadrons (253.527m, 977.093m, -925.668m) (91.5934deg, 267.176deg) 0ns 15741.4GeV nanm Cascade
# ]
#
# ========== I3MCTree_RNGState ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== I3MCTree_postprop ==========
# [I3MCTree:
#   73 NuMu (253.527m, 977.093m, -925.668m) (91.5431deg, 267.176deg) 0ns 51860.9GeV 0m Primary
#     67 MuMinus (253.527m, 977.093m, -925.668m) (91.5212deg, 267.176deg) 0ns 36119.5GeV 3646.43m Dark
#     70 Hadrons (253.527m, 977.093m, -925.668m) (91.5934deg, 267.176deg) 0ns 15741.4GeV nanm Cascade
# ]
#
# ========== I3Photons ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== MMCTrackList ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== Noise_Dark_102_String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== Noise_Dark_160_String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== Noise_Dark_340_String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== Noise_K40_102_String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== Noise_K40_160_String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== Noise_K40_340_String ==========
# <icecube._icetray.I3FrameObject object at 0x151f17cb8580>
#
# ========== PMT_Response_102_String ==========
# []
#
# ========== PMT_Response_160_String ==========
# []
#
# ========== PMT_Response_340_String ==========
# []
#
# ========== PMT_Response_nonoise_102_String ==========
# []
#
# ========== PMT_Response_nonoise_160_String ==========
# []
#
# ========== PMT_Response_nonoise_340_String ==========
# []
#
# ========== trigger_time_102_string ==========
# I3Double(-1)
#
# ========== trigger_time_160_string ==========
# I3Double(-1)
#
# ========== trigger_time_340_string ==========
# I3Double(-1)
#
# ========== triggered_102_string ==========
# I3Double(0)
#
# ========== triggered_160_string ==========
# I3Double(0)
#
# ========== triggered_340_string ==========
# I3Double(0)
