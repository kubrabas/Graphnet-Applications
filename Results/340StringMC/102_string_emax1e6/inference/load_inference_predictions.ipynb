# %%
import pandas as pd

csv_path = "/project/def-nahee/kbas/Graphnet-Applications/Results/340StringMC/102_string_emax1e6/inference/first_category/exp001/inference/inference_predictions.csv"

df = pd.read_csv(csv_path)
df.head()
