# %%
from collections import Counter
import pandas as pd


from icecube import icetray, dataio, LeptonInjector

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
electron_weights = pd.read_csv("/project/def-nahee/kbas/Graphnet-Applications/Metadata/EventWeights/String340MC/Electron_LIW.csv")
muon_weights = pd.read_csv("/project/def-nahee/kbas/Graphnet-Applications/Metadata/EventWeights/String340MC/Muon_LIW.csv")
nc_weights = pd.read_csv("/project/def-nahee/kbas/Graphnet-Applications/Metadata/EventWeights/String340MC/NC_LIW.csv")
tau_weights = pd.read_csv("/project/def-nahee/kbas/Graphnet-Applications/Metadata/EventWeights/String340MC/Tau_LIW.csv")

# %%
electron_log = pd.read_csv("/home/kbas/scratch/String340MC/Logs/LIW/Electron_file_stats.csv")
muon_log = pd.read_csv("/home/kbas/scratch/String340MC/Logs/LIW/Muon_file_stats.csv")
tau_log = pd.read_csv("/home/kbas/scratch/String340MC/Logs/LIW/Tau_file_stats.csv")
nc_log = pd.read_csv("/home/kbas/scratch/String340MC/Logs/LIW/NC_file_stats.csv")

# %% [markdown]
# # Files that 0 event weight (probably because i3 file is not accesible or there is no daq)

# %% [markdown]
# all of these should have
# - status = not_ok
# - weights_calculated = 0
# - and worths to check the error message
# - also, these any of these files should not have any data in flavor_weights

# %% [markdown]
# bunlarin disinda da 0 olabilie btw

# %% [markdown]
# ## Electron

# %%
len(electron_log[electron_log["i3_file_opened_ok"] == False])
# Out:
# 8

# %%
electron_log[electron_log["i3_file_opened_ok"] == False]
# Out:
#       batch_id  \
# 188       1080
# 805       1641
# 855       1687
# 2594       354
# 3759      5235
# 4543      6428
# 4676      6629
# 6631      9619
#
#                                                                                                              lic_file  \
# 188   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1080.lic
# 805   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1641.lic
# 855   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1687.lic
# 2594   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_354.lic
# 3759  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5235.lic
# 4543  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_6428.lic
# 4676  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_6629.lic
# 6631  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9619.lic
#
#                                                                                                              i3_file  \
# 188   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1080.i3.zst
# 805   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1641.i3.zst
# 855   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1687.i3.zst
# 2594   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_354.i3.zst
# 3759  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5235.i3.zst
# 4543  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6428.i3.zst
# 4676  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6629.i3.zst
# 6631  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9619.i3.zst
#
#       status  \
# 188   not ok
# 805   not ok
# 855   not ok
# 2594  not ok
# 3759  not ok
# 4543  not ok
# 4676  not ok
# 6631  not ok
#
#                                                                                                                  error  \
# 188   i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 805   i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 855   i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 2594  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 3759  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 4543  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 4676  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 6631  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 188               False                   0    0.355621
# 805               False                   0    0.291339
# 855               False                   0    0.502012
# 2594              False                   0    0.812702
# 3759              False                   0    0.116117
# 4543              False                   0    0.548010
# 4676              False                   0    0.248657
# 6631              False                   0    0.206379

# %% [markdown]
# #### first idea is to check if these files are completely empthy.

# %%
bad_electrons = electron_log.loc[
    electron_log["i3_file_opened_ok"] == False,
    "i3_file"
]

# %%
# check if there is any kind of frame:

for f in bad_electrons:
    i3 = dataio.I3File(f)

    if not i3.more():
        print("EMPTY:", f)
        i3.close()
        continue

    frame = i3.pop_frame()
    print("READ OK:", f, frame.Stop)

    i3.close()
# Out:
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1080.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1641.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1687.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_354.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5235.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6428.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6629.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9619.i3.zst

# %% [markdown]
# #### What kind of error message we get with this kind of files:

# %%
i3 = dataio.I3File("/project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1080.i3.zst"
)

print("opened")
print("more:", i3.more())
# Out:
# opened
# more: False

# %%
frame = i3.pop_frame()
# Out:
# FATAL (dataio): no frame to pop (I3File.cxx:146 in I3FramePtr dataio::I3File::pop_frame(I3Frame::Stream))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 frame = i3.pop_frame()
#
# RuntimeError: no frame to pop (in I3FramePtr dataio::I3File::pop_frame(I3Frame::Stream))

# %% [markdown]
# so these files should not be taken into account in anything. I added these files to paths.py

# %%
electron_log.loc[
    electron_log["i3_file_opened_ok"] == False,
    "batch_id"].isin(electron_weights["RunID"])
# Out:
# 188     False
# 805     False
# 855     False
# 2594    False
# 3759    False
# 4543    False
# 4676    False
# 6631    False
# Name: batch_id, dtype: bool

# %% [markdown]
# these problematic files are not in my event weight calculations, as it should not be.

# %%
electron_log = electron_log[electron_log["i3_file_opened_ok"] != False]

# %% [markdown]
# #### lets check if there are any other files that has no any event whose weight is calculated

# %%
electron_log[electron_log["weights_calculated"] == 0]
# Out:
# Empty DataFrame
# Columns: [batch_id, lic_file, i3_file, status, error, i3_file_opened_ok, weights_calculated, duration_s]
# Index: []

# %% [markdown]
# there is no. nice.

# %% [markdown]
# ## Muon

# %%
len(muon_log[muon_log["i3_file_opened_ok"] == False])
# Out:
# 5

# %%
muon_log[muon_log["i3_file_opened_ok"] == False]
# Out:
#       batch_id  \
# 4957       546
# 5711       616
# 5844      6282
# 6654       706
# 7553      7930
#
#                                                                                                               lic_file  \
# 4957   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_546.lic
# 5711   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_616.lic
# 5844  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_6282.lic
# 6654   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_706.lic
# 7553  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_7930.lic
#
#                                                                                                        i3_file  \
# 4957   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_546.i3
# 5711   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_616.i3
# 5844  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_6282.i3
# 6654   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_706.i3
# 7553  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_7930.i3
#
#       status  \
# 4957  not ok
# 5711  not ok
# 5844  not ok
# 6654  not ok
# 7553  not ok
#
#                                                                                                                                                         error  \
# 4957                                         i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 5711                                         i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 5844  i3 file problem: read error while reading EventProperties at event 1. 0 EventProperties entries were read before the problem. Error: input stream error
# 6654  i3 file problem: read error while reading EventProperties at event 1. 0 EventProperties entries were read before the problem. Error: input stream error
# 7553  i3 file problem: read error while reading EventProperties at event 1. 0 EventProperties entries were read before the problem. Error: input stream error
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 4957              False                   0    0.084228
# 5711              False                   0    0.239421
# 5844              False                   0    0.022771
# 6654              False                   0    0.118723
# 7553              False                   0    0.181714

# %% [markdown]
# ### first idea is to check if these files are completely empthy.

# %%
bad_muons = muon_log.loc[
    muon_log["i3_file_opened_ok"] == False,
    "i3_file"
]

# %%
for f in bad_muons:
    i3 = None
    try:
        i3 = dataio.I3File(f)
        stops = []

        while i3.more():
            frame = i3.pop_frame()
            stops.append(frame.Stop)

        print("READ OK:", f, stops)

    except RuntimeError as e:
        print("READ ERROR:", f, e)

    finally:
        if i3 is not None:
            i3.close()
# Out:
# READ OK: /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_546.i3 [icetray.I3Frame.TrayInfo]
# READ OK: /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_616.i3 [icetray.I3Frame.TrayInfo]
# READ ERROR: /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_6282.i3 input stream error
# READ ERROR: /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_706.i3 input stream error
# READ ERROR: /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_7930.i3 input stream error

# %%
datasets = {
    "bad_muons": bad_muons}

rows = []

for dataset_name, files in datasets.items():
    for f in files:
        i3 = None
        counts = Counter()
        status = "OK"
        error = ""

        try:
            i3 = dataio.I3File(f)

            while i3.more():
                frame = i3.pop_frame()
                frame_type = str(frame.Stop).split(".")[-1]
                counts[frame_type] += 1

        except Exception as e:
            status = "ERROR"
            error = str(e)

        finally:
            if i3 is not None:
                i3.close()

        row = {
            "file": f,
            "status": status,
            "error": error,
        }
        row.update(counts)
        rows.append(row)

frame_counts_df = pd.DataFrame(rows).fillna(0)

# frame count columnlarını integer yap
meta_cols = ["dataset", "file", "status", "error"]
frame_cols = [c for c in frame_counts_df.columns if c not in meta_cols]
frame_counts_df[frame_cols] = frame_counts_df[frame_cols].astype(int)

frame_counts_df


# status here is different than status in muon_log
# Out:
#                                                                                                        file  \
# 0   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_546.i3
# 1   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_616.i3
# 2  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_6282.i3
# 3   /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_706.i3
# 4  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_7930.i3
#
#   status               error  TrayInfo
# 0     OK                             1
# 1     OK                             1
# 2  ERROR  input stream error         0
# 3  ERROR  input stream error         1
# 4  ERROR  input stream error         0

# %% [markdown]
# Interpretation of frame_counts_df:
#
# - status: OK, error: NA/empty, TrayInfo: 1
#   The file was opened and read successfully. It contains only one readable frame, and that frame is a TrayInfo frame. No DAQ/Physics/event frames were found.
#
# - status: ERROR, error: "input stream error", TrayInfo: 0
#   The file could be opened by I3File, but reading the first frame failed. No readable frames were recovered. This usually indicates a corrupted, truncated, or otherwise invalid I3 stream.
#
# - status: ERROR, error: "input stream error", TrayInfo: 1
#   The file was opened and at least one TrayInfo frame was read successfully, but reading a later frame failed. This suggests the file is partially readable but the stream becomes corrupted or incomplete after the TrayInfo frame.

# %% [markdown]
# so these files should not be taken into account in anything. I added these files to paths.py

# %%
muon_log.loc[
    muon_log["i3_file_opened_ok"] == False,
    "batch_id"].isin(muon_weights["RunID"])
# Out:
# 4957    False
# 5711    False
# 5844    False
# 6654    False
# 7553    False
# Name: batch_id, dtype: bool

# %% [markdown]
# these problematic files are not in my event weight calculations, as it should not be.

# %%
muon_log = muon_log[muon_log["i3_file_opened_ok"] != False]

# %% [markdown]
# lets check if there are any other files that has no any event whose weight is calculated

# %%
muon_log[muon_log["weights_calculated"] == 0]
# Out:
# Empty DataFrame
# Columns: [batch_id, lic_file, i3_file, status, error, i3_file_opened_ok, weights_calculated, duration_s]
# Index: []

# %% [markdown]
# #### there is no. nice.

# %% [markdown]
# ## Tau

# %%
len(tau_log[tau_log["i3_file_opened_ok"] == False])
# Out:
# 1

# %%
tau_log[tau_log["i3_file_opened_ok"] == False]
# Out:
#       batch_id  \
# 3342      3950
#
#                                                                                                                lic_file  \
# 3342  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_3950.lic
#
#                                                                                                                i3_file  \
# 3342  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3950.i3.zst
#
#       status  \
# 3342  not ok
#
#                                                                                                                  error  \
# 3342  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 3342              False                   0     1.23498

# %%
bad_tau = tau_log.loc[
    tau_log["i3_file_opened_ok"] == False,
    "i3_file"
]

# %% [markdown]
# #### first idea is to check if these files are completely empthy.

# %%
bad_tau = tau_log.loc[
    tau_log["i3_file_opened_ok"] == False,
    "i3_file"
]

# %%
# check if there is any kind of frame:

for f in bad_tau:
    i3 = dataio.I3File(f)

    if not i3.more():
        print("EMPTY:", f)
        i3.close()
        continue

    frame = i3.pop_frame()
    print("READ OK:", f, frame.Stop)

    i3.close()
# Out:
# EMPTY: /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3950.i3.zst

# %% [markdown]
# #### What kind of error message we get with this kind of files:

# %%
i3 = dataio.I3File("/project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3950.i3.zst"
)

print("opened")
print("more:", i3.more())
# Out:
# opened
# more: False

# %%
frame = i3.pop_frame()
# Out:
# FATAL (dataio): no frame to pop (I3File.cxx:146 in I3FramePtr dataio::I3File::pop_frame(I3Frame::Stream))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 frame = i3.pop_frame()
#
# RuntimeError: no frame to pop (in I3FramePtr dataio::I3File::pop_frame(I3Frame::Stream))

# %% [markdown]
# so this files should not be taken into account in anything. I added these files to paths.py

# %%
tau_log.loc[
    tau_log["i3_file_opened_ok"] == False,
    "batch_id"].isin(tau_weights["RunID"])
# Out:
# 3342    False
# Name: batch_id, dtype: bool

# %% [markdown]
# this problematic files are not in my event weight calculations, as it should not be.

# %%
tau_log = tau_log[tau_log["i3_file_opened_ok"] != False]

# %% [markdown]
# ##### lets check if there are any other files that has no any event whose weight is calculated

# %%
tau_log[tau_log["weights_calculated"] == 0]
## wtf??????
# Out:
#       batch_id  \
# 2            2
# 4            4
# 5            5
# 8            8
# 9            9
# 11          11
# 12          12
# 1288       208
# 1464       224
# 2586       326
# 2685       335
# 6773       707
# 9215       929
#
#                                                                                                               lic_file  \
# 2     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_002.lic
# 4     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_004.lic
# 5     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_005.lic
# 8     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_008.lic
# 9     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_009.lic
# 11    /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_011.lic
# 12    /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_012.lic
# 1288  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_208.lic
# 1464  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_224.lic
# 2586  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_326.lic
# 2685  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_335.lic
# 6773  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_707.lic
# 9215  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_929.lic
#
#                                                                                                               i3_file  \
# 2     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_002.i3.zst
# 4     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_004.i3.zst
# 5     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_005.i3.zst
# 8     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_008.i3.zst
# 9     /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_009.i3.zst
# 11    /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_011.i3.zst
# 12    /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_012.i3.zst
# 1288  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_208.i3.zst
# 1464  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_224.i3.zst
# 2586  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_326.i3.zst
# 2685  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_335.i3.zst
# 6773  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_707.i3.zst
# 9215  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_929.i3.zst
#
#       status  \
# 2     not ok
# 4     not ok
# 5     not ok
# 8     not ok
# 9     not ok
# 11    not ok
# 12    not ok
# 1288  not ok
# 1464  not ok
# 2586  not ok
# 2685  not ok
# 6773  not ok
# 9215  not ok
#
#                                                                                                                                                                                     error  \
# 2     weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 4     weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 5     weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 8     weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 9     weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 11    weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 12    weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 1288  weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 1464  weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 2586  weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 2685  weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 6773  weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
# 9215  weighting problem at event 1: oneweight could not be computed. 0 event weights were calculated before the problem. Error: Out of declared generation phase space. Impossible event.
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 2                  True                   0    0.622973
# 4                  True                   0    0.563813
# 5                  True                   0    1.393014
# 8                  True                   0    1.169254
# 9                  True                   0    0.610393
# 11                 True                   0    0.982062
# 12                 True                   0    0.563346
# 1288               True                   0    1.271524
# 1464               True                   0    3.312323
# 2586               True                   0    0.165988
# 2685               True                   0    2.853694
# 6773               True                   0    0.506848
# 9215               True                   0    0.455145

# %%
len(tau_log[tau_log["weights_calculated"] == 0])
 
#  I NEED TO LOOK HERE IN MORE DETAIL!
# Out:
# 13

# %% [markdown]
# ## NC

# %%
len(nc_log[nc_log["i3_file_opened_ok"] == False])
# Out:
# 2

# %%
nc_log[nc_log["i3_file_opened_ok"] == False]
# Out:
#       batch_id  \
# 1569      2335
# 8961      9055
#
#                                                                                                                  lic_file  \
# 1569  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_2335.lic
# 8961  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_9055.lic
#
#                                                                                                                  i3_file  \
# 1569  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2335.i3.zst
# 8961  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_9055.i3.zst
#
#       status  \
# 1569  not ok
# 8961  not ok
#
#                                                                                                                  error  \
# 1569  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
# 8961  i3 file problem: no DAQ frames with EventProperties and I3EventHeader were found in the EventProperties i3 file.
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 1569              False                   0    0.263894
# 8961              False                   0    0.939840

# %% [markdown]
# ### first idea is to check if these files are completely empthy.

# %%
bad_nc = nc_log.loc[
    nc_log["i3_file_opened_ok"] == False,
    "i3_file"
]

# %%
# check if there is any kind of frame:

for f in bad_nc:
    i3 = dataio.I3File(f)

    if not i3.more():
        print("EMPTY:", f)
        i3.close()
        continue

    frame = i3.pop_frame()
    print("READ OK:", f, frame.Stop)

    i3.close()
# Out:
# EMPTY: /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2335.i3.zst
# EMPTY: /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_9055.i3.zst

# %% [markdown]
# #### What kind of error message we get with this kind of files:

# %%
i3 = dataio.I3File("/project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2335.i3.zst")

print("opened")
print("more:", i3.more())
# Out:
# opened
# more: False

# %%
frame = i3.pop_frame()
# Out:
# FATAL (dataio): no frame to pop (I3File.cxx:146 in I3FramePtr dataio::I3File::pop_frame(I3Frame::Stream))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 frame = i3.pop_frame()
#
# RuntimeError: no frame to pop (in I3FramePtr dataio::I3File::pop_frame(I3Frame::Stream))

# %% [markdown]
# ##### so these files should not be taken into account in anything. I added these files to paths.py

# %%
nc_log.loc[
    nc_log["i3_file_opened_ok"] == False,
    "batch_id"].isin(nc_weights["RunID"])
# Out:
# 1569    False
# 8961    False
# Name: batch_id, dtype: bool

# %% [markdown]
# these problematic files are not in my event weight calculations, as it should not be.

# %%
nc_log = nc_log[nc_log["i3_file_opened_ok"] != False]

# %% [markdown]
# lets check if there are any other files that has no any event whose weight is calculated

# %%
nc_log[nc_log["weights_calculated"] == 0]
# Out:
# Empty DataFrame
# Columns: [batch_id, lic_file, i3_file, status, error, i3_file_opened_ok, weights_calculated, duration_s]
# Index: []

# %% [markdown]
# there is no. nice.

# %% [markdown]
# # I3 Files That Has < 200 & > 0 Available Events
# knk bunlari check et output dosyanda da bu miktarda event weight mi hesaplandu.
# her sey bitince buyuk analiz yap. total. available event count vs diye. buyuk tablo istiyorum ne asamada ne kadar event available diye.
# bu script bitince python'a duzenlet

# %% [markdown]
# ## Electron

# %%
len(electron_log[
    (electron_log["weights_calculated"] > 0) &
    (electron_log["weights_calculated"] < 200)
])
# Out:
# 31

# %%
electron_log[
    (electron_log["weights_calculated"] > 0) &
    (electron_log["weights_calculated"] < 200)
].head()
# Out:
#       batch_id  \
# 265       1150
# 641       1492
# 1599      2363
# 1644      2404
# 1659      2418
#
#                                                                                                              lic_file  \
# 265   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1150.lic
# 641   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1492.lic
# 1599  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_2363.lic
# 1644  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_2404.lic
# 1659  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_2418.lic
#
#                                                                                                              i3_file  \
# 265   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1150.i3.zst
# 641   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1492.i3.zst
# 1599  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2363.i3.zst
# 1644  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2404.i3.zst
# 1659  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2418.i3.zst
#
#             status  \
# 265   partially ok
# 641   partially ok
# 1599  partially ok
# 1644  partially ok
# 1659  partially ok
#
#                                                                                                                                                                                                                                                                                         error  \
# 265   i3 file problem: read error while reading EventProperties at event 166. 165 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 166: read error. 165 event weights were calculated before the problem. Error: input stream error
# 641   i3 file problem: read error while reading EventProperties at event 123. 122 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 123: read error. 122 event weights were calculated before the problem. Error: input stream error
# 1599    i3 file problem: read error while reading EventProperties at event 100. 99 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 100: read error. 99 event weights were calculated before the problem. Error: input stream error
# 1644      i3 file problem: read error while reading EventProperties at event 80. 79 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 80: read error. 79 event weights were calculated before the problem. Error: input stream error
# 1659  i3 file problem: read error while reading EventProperties at event 118. 117 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 118: read error. 117 event weights were calculated before the problem. Error: input stream error
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 265                True                 165    0.507415
# 641                True                 122    0.951075
# 1599               True                  99    1.290242
# 1644               True                  79    2.907490
# 1659               True                 117    0.686976

# %%
# weights_calculated comes from the LIW processing log CSV.
# truth_rows and max_event_id come from the produced LIW weights CSV, grouped by RunID.
electron_partial_compare_summary = (
    electron_weights.groupby("RunID", as_index=False)
    .agg(
        # Number of rows found in the LIW weights CSV for this RunID.
        truth_rows=("EventID", "size"),
        # Largest EventID found in the LIW weights CSV for this RunID.
        max_event_id=("EventID", "max"),
    )
    .rename(columns={"RunID": "batch_id"})
)

electron_partial_compare = (
    electron_log[
        (electron_log["weights_calculated"] > 0) &
        (electron_log["weights_calculated"] < 200)
    ][["batch_id", "i3_file", "weights_calculated"]]
    .merge(
        electron_partial_compare_summary,
        on="batch_id",
        how="left",
    )
    .sort_values("batch_id")
)

print("Electron: weights_calculated == max_event_id")
print((electron_partial_compare["weights_calculated"] == electron_partial_compare["max_event_id"]).value_counts(dropna=False))
print()
print("Electron: truth_rows == weights_calculated")
print((electron_partial_compare["truth_rows"] == electron_partial_compare["weights_calculated"]).value_counts(dropna=False))
print()

electron_partial_compare
# Out:
# Electron: weights_calculated == max_event_id
# True    31
# Name: count, dtype: int64
#
# Electron: truth_rows == weights_calculated
# True    31
# Name: count, dtype: int64
#     batch_id  \
# 13       590
# 16       703
# 21       771
# 26       880
# 29       976
# 30       989
# 0       1150
# 1       1492
# 2       2363
# 3       2404
# 4       2418
# 5       2798
# 6       2959
# 7       3157
# 8       3491
# 9       3882
# 10      3930
# 11      4415
# 12      5257
# 14      5971
# 15      6044
# 17      7084
# 18      7383
# 19      7504
# 20      7615
# 22      8150
# 23      8164
# 24      8222
# 25      8779
# 27      9287
# 28      9361
#
#                                                                                                            i3_file  \
# 13   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_590.i3.zst
# 16   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_703.i3.zst
# 21   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_771.i3.zst
# 26   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_880.i3.zst
# 29   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_976.i3.zst
# 30   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_989.i3.zst
# 0   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1150.i3.zst
# 1   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1492.i3.zst
# 2   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2363.i3.zst
# 3   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2404.i3.zst
# 4   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2418.i3.zst
# 5   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2798.i3.zst
# 6   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2959.i3.zst
# 7   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3157.i3.zst
# 8   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3491.i3.zst
# 9   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3882.i3.zst
# 10  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3930.i3.zst
# 11  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4415.i3.zst
# 12  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5257.i3.zst
# 14  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5971.i3.zst
# 15  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6044.i3.zst
# 17  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7084.i3.zst
# 18  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7383.i3.zst
# 19  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7504.i3.zst
# 20  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7615.i3.zst
# 22  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8150.i3.zst
# 23  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8164.i3.zst
# 24  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8222.i3.zst
# 25  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8779.i3.zst
# 27  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9287.i3.zst
# 28  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9361.i3.zst
#
#     weights_calculated  truth_rows  max_event_id
# 13                  23          23            23
# 16                   8           8             8
# 21                  49          49            49
# 26                 119         119           119
# 29                 133         133           133
# 30                  17          17            17
# 0                  165         165           165
# 1                  122         122           122
# 2                   99          99            99
# 3                   79          79            79
# 4                  117         117           117
# 5                  122         122           122
# 6                  158         158           158
# 7                   30          30            30
# 8                  169         169           169
# 9                  174         174           174
# 10                 140         140           140
# 11                 139         139           139
# 12                 127         127           127
# 14                  30          30            30
# 15                  32          32            32
# 17                  16          16            16
# 18                  55          55            55
# 19                  76          76            76
# 20                 121         121           121
# 22                 127         127           127
# 23                 152         152           152
# 24                  81          81            81
# 25                  18          18            18
# 27                 115         115           115
# 28                  96          96            96

# %% [markdown]
# #### let's check from scratch how many frame are available

# %%
rows = []

for i3_file in electron_log[
    (electron_log["weights_calculated"] > 0) &
    (electron_log["weights_calculated"] < 200)
]["i3_file"]:
    counts = Counter()
    error = ""

    try:
        f = dataio.I3File(str(i3_file))

        while f.more():
            try:
                frame = f.pop_frame()
            except Exception as e:
                error = str(e)
                break

            counts[str(frame.Stop)] += 1

        f.close()

    except Exception as e:
        error = str(e)

    rows.append({
        "i3_file": i3_file,
        "DAQ": counts[str(icetray.I3Frame.DAQ)],
        "TrayInfo": counts[str(icetray.I3Frame.TrayInfo)],
        "Geometry": counts[str(icetray.I3Frame.Geometry)],
        "Calibration": counts[str(icetray.I3Frame.Calibration)],
        "DetectorStatus": counts[str(icetray.I3Frame.DetectorStatus)],
        "Physics": counts[str(icetray.I3Frame.Physics)],
        "error": error,
    })

frame_counts = pd.DataFrame(rows)
frame_counts
# Out:
#                                                                                                            i3_file  \
# 0   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1150.i3.zst
# 1   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1492.i3.zst
# 2   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2363.i3.zst
# 3   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2404.i3.zst
# 4   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2418.i3.zst
# 5   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2798.i3.zst
# 6   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2959.i3.zst
# 7   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3157.i3.zst
# 8   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3491.i3.zst
# 9   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3882.i3.zst
# 10  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3930.i3.zst
# 11  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4415.i3.zst
# 12  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5257.i3.zst
# 13   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_590.i3.zst
# 14  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5971.i3.zst
# 15  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6044.i3.zst
# 16   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_703.i3.zst
# 17  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7084.i3.zst
# 18  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7383.i3.zst
# 19  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7504.i3.zst
# 20  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7615.i3.zst
# 21   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_771.i3.zst
# 22  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8150.i3.zst
# 23  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8164.i3.zst
# 24  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8222.i3.zst
# 25  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8779.i3.zst
# 26   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_880.i3.zst
# 27  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9287.i3.zst
# 28  /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9361.i3.zst
# 29   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_976.i3.zst
# 30   /project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_989.i3.zst
#
#     DAQ  TrayInfo  Geometry  Calibration  DetectorStatus  Physics  \
# 0   165         1         0            0               0        0
# 1   122         1         0            0               0        0
# 2    99         1         0            0               0        0
# 3    79         1         0            0               0        0
# 4   117         1         0            0               0        0
# 5   122         1         0            0               0        0
# 6   158         1         0            0               0        0
# 7    30         1         0            0               0        0
# 8   169         1         0            0               0        0
# 9   174         1         0            0               0        0
# 10  140         1         0            0               0        0
# 11  139         1         0            0               0        0
# 12  127         1         0            0               0        0
# 13   23         1         0            0               0        0
# 14   30         1         0            0               0        0
# 15   32         1         0            0               0        0
# 16    8         1         0            0               0        0
# 17   16         1         0            0               0        0
# 18   55         1         0            0               0        0
# 19   76         1         0            0               0        0
# 20  121         1         0            0               0        0
# 21   49         1         0            0               0        0
# 22  127         1         0            0               0        0
# 23  152         1         0            0               0        0
# 24   81         1         0            0               0        0
# 25   18         1         0            0               0        0
# 26  119         1         0            0               0        0
# 27  115         1         0            0               0        0
# 28   96         1         0            0               0        0
# 29  133         1         0            0               0        0
# 30   17         1         0            0               0        0
#
#                  error
# 0   input stream error
# 1   input stream error
# 2   input stream error
# 3   input stream error
# 4   input stream error
# 5   input stream error
# 6   input stream error
# 7   input stream error
# 8   input stream error
# 9   input stream error
# 10  input stream error
# 11  input stream error
# 12  input stream error
# 13  input stream error
# 14  input stream error
# 15  input stream error
# 16  input stream error
# 17  input stream error
# 18  input stream error
# 19  input stream error
# 20  input stream error
# 21  input stream error
# 22  input stream error
# 23  input stream error
# 24  input stream error
# 25  input stream error
# 26  input stream error
# 27  input stream error
# 28  input stream error
# 29  input stream error
# 30  input stream error

# %% [markdown]
# so oll of them has "input stream error" which means events after some point are not reachable. I note this in paths.py

# %% [markdown]
# ## Muon

# %%
len(muon_log[
    (muon_log["weights_calculated"] > 0) &
    (muon_log["weights_calculated"] < 200)
])
# Out:
# 223

# %%
muon_log[
    (muon_log["weights_calculated"] > 0) &
    (muon_log["weights_calculated"] < 200)
]
# Out:
#       batch_id  \
# 19          19
# 30          30
# 38          38
# 83          84
# 88          89
# ...        ...
# 9439      9656
# 9451      9667
# 9453      9669
# 9518      9728
# 9797      9981
#
#                                                                                                               lic_file  \
# 19     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_019.lic
# 30     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_030.lic
# 38     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_038.lic
# 83     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_084.lic
# 88     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_089.lic
# ...                                                                                                                ...
# 9439  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_9656.lic
# 9451  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_9667.lic
# 9453  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_9669.lic
# 9518  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_9728.lic
# 9797  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Generator/genCard_9981.lic
#
#                                                                                                        i3_file  \
# 19     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_019.i3
# 30     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_030.i3
# 38     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_038.i3
# 83     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_084.i3
# 88     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_089.i3
# ...                                                                                                        ...
# 9439  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9656.i3
# 9451  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9667.i3
# 9453  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9669.i3
# 9518  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9728.i3
# 9797  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9981.i3
#
#             status  \
# 19    partially ok
# 30    partially ok
# 38    partially ok
# 83    partially ok
# 88    partially ok
# ...            ...
# 9439  partially ok
# 9451  partially ok
# 9453  partially ok
# 9518  partially ok
# 9797  partially ok
#
#                                                                                                                                                                                                                                                                                         error  \
# 19                                                                                                                                                                                                                                                                                    unknown
# 30                                                                                                                                                                                                                                                                                    unknown
# 38    i3 file problem: read error while reading EventProperties at event 189. 188 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 189: read error. 188 event weights were calculated before the problem. Error: input stream error
# 83                                                                                                                                                                                                                                                                                    unknown
# 88                                                                                                                                                                                                                                                                                    unknown
# ...                                                                                                                                                                                                                                                                                       ...
# 9439      i3 file problem: read error while reading EventProperties at event 39. 38 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 39: read error. 38 event weights were calculated before the problem. Error: input stream error
# 9451  i3 file problem: read error while reading EventProperties at event 171. 170 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 171: read error. 170 event weights were calculated before the problem. Error: input stream error
# 9453          i3 file problem: read error while reading EventProperties at event 5. 4 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 5: read error. 4 event weights were calculated before the problem. Error: input stream error
# 9518      i3 file problem: read error while reading EventProperties at event 15. 14 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 15: read error. 14 event weights were calculated before the problem. Error: input stream error
# 9797      i3 file problem: read error while reading EventProperties at event 22. 21 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 22: read error. 21 event weights were calculated before the problem. Error: input stream error
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 19                 True                 110    0.507658
# 30                 True                 185    2.570113
# 38                 True                 188    4.259287
# 83                 True                  63    0.386007
# 88                 True                  96    3.225122
# ...                 ...                 ...         ...
# 9439               True                  38    2.469903
# 9451               True                 170    0.532698
# 9453               True                   4    0.267919
# 9518               True                  14    1.176097
# 9797               True                  21    0.696950
#
# [223 rows x 8 columns]

# %%
# weights_calculated comes from the LIW processing log CSV.
# truth_rows and max_event_id come from the produced LIW weights CSV, grouped by RunID.
muon_partial_compare_summary = (
    muon_weights.groupby("RunID", as_index=False)
    .agg(
        # Number of rows found in the LIW weights CSV for this RunID.
        truth_rows=("EventID", "size"),
        # Largest EventID found in the LIW weights CSV for this RunID.
        max_event_id=("EventID", "max"),
    )
    .rename(columns={"RunID": "batch_id"})
)

muon_partial_compare = (
    muon_log[
        (muon_log["weights_calculated"] > 0) &
        (muon_log["weights_calculated"] < 200)
    ][["batch_id", "i3_file", "weights_calculated"]]
    .merge(
        muon_partial_compare_summary,
        on="batch_id",
        how="left",
    )
    .sort_values("batch_id")
)

print("Muon: weights_calculated == max_event_id")
print((muon_partial_compare["weights_calculated"] == muon_partial_compare["max_event_id"]).value_counts(dropna=False))
print()
print("Muon: truth_rows == weights_calculated")
print((muon_partial_compare["truth_rows"] == muon_partial_compare["weights_calculated"]).value_counts(dropna=False))
print()

muon_partial_compare
# Out:
# Muon: weights_calculated == max_event_id
# True    223
# Name: count, dtype: int64
#
# Muon: truth_rows == weights_calculated
# True    223
# Name: count, dtype: int64
#      batch_id  \
# 0          19
# 1          30
# 2          38
# 3          84
# 4          89
# ..        ...
# 218      9656
# 219      9667
# 220      9669
# 221      9728
# 222      9981
#
#                                                                                                       i3_file  \
# 0     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_019.i3
# 1     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_030.i3
# 2     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_038.i3
# 3     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_084.i3
# 4     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_089.i3
# ..                                                                                                        ...
# 218  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9656.i3
# 219  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9667.i3
# 220  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9669.i3
# 221  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9728.i3
# 222  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9981.i3
#
#      weights_calculated  truth_rows  max_event_id
# 0                   110         110           110
# 1                   185         185           185
# 2                   188         188           188
# 3                    63          63            63
# 4                    96          96            96
# ..                  ...         ...           ...
# 218                  38          38            38
# 219                 170         170           170
# 220                   4           4             4
# 221                  14          14            14
# 222                  21          21            21
#
# [223 rows x 5 columns]

# %%
rows = []

for i3_file in muon_log[
    (muon_log["weights_calculated"] > 0) &
    (muon_log["weights_calculated"] < 200)
]["i3_file"]:
    counts = Counter()
    error = ""

    try:
        f = dataio.I3File(str(i3_file))

        while f.more():
            try:
                frame = f.pop_frame()
            except Exception as e:
                error = str(e)
                break

            counts[str(frame.Stop)] += 1

        f.close()

    except Exception as e:
        error = str(e)

    rows.append({
        "i3_file": i3_file,
        "DAQ": counts[str(icetray.I3Frame.DAQ)],
        "TrayInfo": counts[str(icetray.I3Frame.TrayInfo)],
        "Geometry": counts[str(icetray.I3Frame.Geometry)],
        "Calibration": counts[str(icetray.I3Frame.Calibration)],
        "DetectorStatus": counts[str(icetray.I3Frame.DetectorStatus)],
        "Physics": counts[str(icetray.I3Frame.Physics)],
        "error": error,
    })

frame_counts = pd.DataFrame(rows)
frame_counts
# Out:
#                                                                                                       i3_file  \
# 0     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_019.i3
# 1     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_030.i3
# 2     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_038.i3
# 3     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_084.i3
# 4     /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_089.i3
# ..                                                                                                        ...
# 218  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9656.i3
# 219  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9667.i3
# 220  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9669.i3
# 221  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9728.i3
# 222  /project/6008051/pone_simulation/MC000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim-v10/Photon/cls_9981.i3
#
#      DAQ  TrayInfo  Geometry  Calibration  DetectorStatus  Physics  \
# 0    110         1         0            0               0        0
# 1    185         1         0            0               0        0
# 2    188         1         0            0               0        0
# 3     63         1         0            0               0        0
# 4     96         1         0            0               0        0
# ..   ...       ...       ...          ...             ...      ...
# 218   38         1         0            0               0        0
# 219  170         1         0            0               0        0
# 220    4         1         0            0               0        0
# 221   14         1         0            0               0        0
# 222   21         1         0            0               0        0
#
#                   error
# 0
# 1
# 2    input stream error
# 3
# 4
# ..                  ...
# 218  input stream error
# 219  input stream error
# 220  input stream error
# 221  input stream error
# 222  input stream error
#
# [223 rows x 8 columns]

# %% [markdown]
# ## Tau

# %%
len(tau_log[
    (tau_log["weights_calculated"] > 0) &
    (tau_log["weights_calculated"] < 200)
]
)
# Out:
# 34

# %%
tau_log[
    (tau_log["weights_calculated"] > 0) &
    (tau_log["weights_calculated"] < 200)
]
# Out:
#       batch_id  \
# 116       1014
# 368       1243
# 719       1562
# 1553      2320
# 2426      3114
# 2556      3232
# 3022      3656
# 3027      3660
# 3351      3959
# 3648      4229
# 4129      4666
# 4875      5344
# 4989      5448
# 5022      5478
# 5350      5776
# 5353      5779
# 5496      5909
# 5620      6021
# 6219      6566
# 6563      6879
# 6900      7185
# 6920      7203
# 7198      7456
# 7203      7460
# 7698      7910
# 7989      8175
# 8364      8516
# 8805      8917
# 8964      9061
# 9170      9249
# 9302      9369
# 9361      9422
# 9467      9519
# 9639      9675
#
#                                                                                                                lic_file  \
# 116   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1014.lic
# 368   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1243.lic
# 719   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_1562.lic
# 1553  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_2320.lic
# 2426  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_3114.lic
# 2556  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_3232.lic
# 3022  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_3656.lic
# 3027  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_3660.lic
# 3351  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_3959.lic
# 3648  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_4229.lic
# 4129  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_4666.lic
# 4875  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5344.lic
# 4989  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5448.lic
# 5022  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5478.lic
# 5350  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5776.lic
# 5353  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5779.lic
# 5496  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_5909.lic
# 5620  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_6021.lic
# 6219  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_6566.lic
# 6563  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_6879.lic
# 6900  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_7185.lic
# 6920  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_7203.lic
# 7198  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_7456.lic
# 7203  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_7460.lic
# 7698  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_7910.lic
# 7989  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_8175.lic
# 8364  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_8516.lic
# 8805  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_8917.lic
# 8964  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9061.lic
# 9170  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9249.lic
# 9302  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9369.lic
# 9361  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9422.lic
# 9467  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9519.lic
# 9639  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/genCard_9675.lic
#
#                                                                                                                i3_file  \
# 116   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1014.i3.zst
# 368   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1243.i3.zst
# 719   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1562.i3.zst
# 1553  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2320.i3.zst
# 2426  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3114.i3.zst
# 2556  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3232.i3.zst
# 3022  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3656.i3.zst
# 3027  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3660.i3.zst
# 3351  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3959.i3.zst
# 3648  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4229.i3.zst
# 4129  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4666.i3.zst
# 4875  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5344.i3.zst
# 4989  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5448.i3.zst
# 5022  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5478.i3.zst
# 5350  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5776.i3.zst
# 5353  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5779.i3.zst
# 5496  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5909.i3.zst
# 5620  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6021.i3.zst
# 6219  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6566.i3.zst
# 6563  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6879.i3.zst
# 6900  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7185.i3.zst
# 6920  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7203.i3.zst
# 7198  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7456.i3.zst
# 7203  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7460.i3.zst
# 7698  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7910.i3.zst
# 7989  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8175.i3.zst
# 8364  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8516.i3.zst
# 8805  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8917.i3.zst
# 8964  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9061.i3.zst
# 9170  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9249.i3.zst
# 9302  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9369.i3.zst
# 9361  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9422.i3.zst
# 9467  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9519.i3.zst
# 9639  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9675.i3.zst
#
#             status  \
# 116   partially ok
# 368   partially ok
# 719   partially ok
# 1553  partially ok
# 2426  partially ok
# 2556  partially ok
# 3022  partially ok
# 3027  partially ok
# 3351  partially ok
# 3648  partially ok
# 4129  partially ok
# 4875  partially ok
# 4989  partially ok
# 5022  partially ok
# 5350  partially ok
# 5353  partially ok
# 5496  partially ok
# 5620  partially ok
# 6219  partially ok
# 6563  partially ok
# 6900  partially ok
# 6920  partially ok
# 7198  partially ok
# 7203  partially ok
# 7698  partially ok
# 7989  partially ok
# 8364  partially ok
# 8805  partially ok
# 8964  partially ok
# 9170  partially ok
# 9302  partially ok
# 9361  partially ok
# 9467  partially ok
# 9639  partially ok
#
#                                                                                                                                                                                                                                                                                         error  \
# 116   i3 file problem: read error while reading EventProperties at event 108. 107 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 108: read error. 107 event weights were calculated before the problem. Error: input stream error
# 368   i3 file problem: read error while reading EventProperties at event 107. 106 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 107: read error. 106 event weights were calculated before the problem. Error: input stream error
# 719   i3 file problem: read error while reading EventProperties at event 145. 144 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 145: read error. 144 event weights were calculated before the problem. Error: input stream error
# 1553      i3 file problem: read error while reading EventProperties at event 77. 76 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 77: read error. 76 event weights were calculated before the problem. Error: input stream error
# 2426      i3 file problem: read error while reading EventProperties at event 12. 11 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 12: read error. 11 event weights were calculated before the problem. Error: input stream error
# 2556  i3 file problem: read error while reading EventProperties at event 183. 182 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 183: read error. 182 event weights were calculated before the problem. Error: input stream error
# 3022  i3 file problem: read error while reading EventProperties at event 130. 129 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 130: read error. 129 event weights were calculated before the problem. Error: input stream error
# 3027      i3 file problem: read error while reading EventProperties at event 13. 12 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 13: read error. 12 event weights were calculated before the problem. Error: input stream error
# 3351  i3 file problem: read error while reading EventProperties at event 122. 121 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 122: read error. 121 event weights were calculated before the problem. Error: input stream error
# 3648  i3 file problem: read error while reading EventProperties at event 138. 137 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 138: read error. 137 event weights were calculated before the problem. Error: input stream error
# 4129      i3 file problem: read error while reading EventProperties at event 16. 15 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 16: read error. 15 event weights were calculated before the problem. Error: input stream error
# 4875      i3 file problem: read error while reading EventProperties at event 90. 89 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 90: read error. 89 event weights were calculated before the problem. Error: input stream error
# 4989      i3 file problem: read error while reading EventProperties at event 42. 41 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 42: read error. 41 event weights were calculated before the problem. Error: input stream error
# 5022      i3 file problem: read error while reading EventProperties at event 95. 94 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 95: read error. 94 event weights were calculated before the problem. Error: input stream error
# 5350  i3 file problem: read error while reading EventProperties at event 124. 123 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 124: read error. 123 event weights were calculated before the problem. Error: input stream error
# 5353  i3 file problem: read error while reading EventProperties at event 123. 122 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 123: read error. 122 event weights were calculated before the problem. Error: input stream error
# 5496      i3 file problem: read error while reading EventProperties at event 60. 59 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 60: read error. 59 event weights were calculated before the problem. Error: input stream error
# 5620  i3 file problem: read error while reading EventProperties at event 133. 132 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 133: read error. 132 event weights were calculated before the problem. Error: input stream error
# 6219      i3 file problem: read error while reading EventProperties at event 88. 87 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 88: read error. 87 event weights were calculated before the problem. Error: input stream error
# 6563          i3 file problem: read error while reading EventProperties at event 9. 8 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 9: read error. 8 event weights were calculated before the problem. Error: input stream error
# 6900      i3 file problem: read error while reading EventProperties at event 59. 58 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 59: read error. 58 event weights were calculated before the problem. Error: input stream error
# 6920      i3 file problem: read error while reading EventProperties at event 77. 76 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 77: read error. 76 event weights were calculated before the problem. Error: input stream error
# 7198      i3 file problem: read error while reading EventProperties at event 24. 23 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 24: read error. 23 event weights were calculated before the problem. Error: input stream error
# 7203      i3 file problem: read error while reading EventProperties at event 96. 95 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 96: read error. 95 event weights were calculated before the problem. Error: input stream error
# 7698  i3 file problem: read error while reading EventProperties at event 116. 115 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 116: read error. 115 event weights were calculated before the problem. Error: input stream error
# 7989  i3 file problem: read error while reading EventProperties at event 110. 109 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 110: read error. 109 event weights were calculated before the problem. Error: input stream error
# 8364      i3 file problem: read error while reading EventProperties at event 15. 14 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 15: read error. 14 event weights were calculated before the problem. Error: input stream error
# 8805      i3 file problem: read error while reading EventProperties at event 56. 55 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 56: read error. 55 event weights were calculated before the problem. Error: input stream error
# 8964      i3 file problem: read error while reading EventProperties at event 45. 44 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 45: read error. 44 event weights were calculated before the problem. Error: input stream error
# 9170      i3 file problem: read error while reading EventProperties at event 32. 31 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 32: read error. 31 event weights were calculated before the problem. Error: input stream error
# 9302  i3 file problem: read error while reading EventProperties at event 145. 144 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 145: read error. 144 event weights were calculated before the problem. Error: input stream error
# 9361      i3 file problem: read error while reading EventProperties at event 64. 63 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 64: read error. 63 event weights were calculated before the problem. Error: input stream error
# 9467  i3 file problem: read error while reading EventProperties at event 165. 164 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 165: read error. 164 event weights were calculated before the problem. Error: input stream error
# 9639  i3 file problem: read error while reading EventProperties at event 170. 169 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 170: read error. 169 event weights were calculated before the problem. Error: input stream error
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 116                True                 107    2.350324
# 368                True                 106    0.664493
# 719                True                 144    1.101861
# 1553               True                  76    0.919520
# 2426               True                  11    0.556284
# 2556               True                 182    2.460599
# 3022               True                 129    3.178279
# 3027               True                  12    2.456454
# 3351               True                 121    4.897202
# 3648               True                 137    0.384759
# 4129               True                  15    1.366864
# 4875               True                  89    0.251837
# 4989               True                  41    0.850878
# 5022               True                  94    0.355232
# 5350               True                 123    0.705724
# 5353               True                 122    0.701511
# 5496               True                  59    0.614609
# 5620               True                 132    0.291633
# 6219               True                  87    0.645939
# 6563               True                   8    0.579138
# 6900               True                  58    0.638451
# 6920               True                  76    0.188897
# 7198               True                  23    0.627728
# 7203               True                  95    0.552007
# 7698               True                 115    0.297923
# 7989               True                 109    1.833887
# 8364               True                  14    0.359369
# 8805               True                  55    0.339861
# 8964               True                  44    0.413203
# 9170               True                  31    1.763124
# 9302               True                 144    1.462144
# 9361               True                  63    0.439408
# 9467               True                 164    0.575814
# 9639               True                 169    0.537747

# %%
# weights_calculated comes from the LIW processing log CSV.
# truth_rows and max_event_id come from the produced LIW weights CSV, grouped by RunID.
tau_partial_compare_summary = (
    tau_weights.groupby("RunID", as_index=False)
    .agg(
        # Number of rows found in the LIW weights CSV for this RunID.
        truth_rows=("EventID", "size"),
        # Largest EventID found in the LIW weights CSV for this RunID.
        max_event_id=("EventID", "max"),
    )
    .rename(columns={"RunID": "batch_id"})
)

tau_partial_compare = (
    tau_log[
        (tau_log["weights_calculated"] > 0) &
        (tau_log["weights_calculated"] < 200)
    ][["batch_id", "i3_file", "weights_calculated"]]
    .merge(
        tau_partial_compare_summary,
        on="batch_id",
        how="left",
    )
    .sort_values("batch_id")
)

print("Tau: weights_calculated == max_event_id")
print((tau_partial_compare["weights_calculated"] == tau_partial_compare["max_event_id"]).value_counts(dropna=False))
print()
print("Tau: truth_rows == weights_calculated")
print((tau_partial_compare["truth_rows"] == tau_partial_compare["weights_calculated"]).value_counts(dropna=False))
print()

tau_partial_compare
# Out:
# Tau: weights_calculated == max_event_id
# True    34
# Name: count, dtype: int64
#
# Tau: truth_rows == weights_calculated
# True    34
# Name: count, dtype: int64
#     batch_id  \
# 0       1014
# 1       1243
# 2       1562
# 3       2320
# 4       3114
# 5       3232
# 6       3656
# 7       3660
# 8       3959
# 9       4229
# 10      4666
# 11      5344
# 12      5448
# 13      5478
# 14      5776
# 15      5779
# 16      5909
# 17      6021
# 18      6566
# 19      6879
# 20      7185
# 21      7203
# 22      7456
# 23      7460
# 24      7910
# 25      8175
# 26      8516
# 27      8917
# 28      9061
# 29      9249
# 30      9369
# 31      9422
# 32      9519
# 33      9675
#
#                                                                                                              i3_file  \
# 0   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1014.i3.zst
# 1   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1243.i3.zst
# 2   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1562.i3.zst
# 3   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2320.i3.zst
# 4   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3114.i3.zst
# 5   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3232.i3.zst
# 6   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3656.i3.zst
# 7   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3660.i3.zst
# 8   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3959.i3.zst
# 9   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4229.i3.zst
# 10  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4666.i3.zst
# 11  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5344.i3.zst
# 12  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5448.i3.zst
# 13  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5478.i3.zst
# 14  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5776.i3.zst
# 15  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5779.i3.zst
# 16  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5909.i3.zst
# 17  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6021.i3.zst
# 18  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6566.i3.zst
# 19  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6879.i3.zst
# 20  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7185.i3.zst
# 21  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7203.i3.zst
# 22  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7456.i3.zst
# 23  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7460.i3.zst
# 24  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7910.i3.zst
# 25  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8175.i3.zst
# 26  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8516.i3.zst
# 27  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8917.i3.zst
# 28  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9061.i3.zst
# 29  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9249.i3.zst
# 30  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9369.i3.zst
# 31  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9422.i3.zst
# 32  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9519.i3.zst
# 33  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9675.i3.zst
#
#     weights_calculated  truth_rows  max_event_id
# 0                  107         107           107
# 1                  106         106           106
# 2                  144         144           144
# 3                   76          76            76
# 4                   11          11            11
# 5                  182         182           182
# 6                  129         129           129
# 7                   12          12            12
# 8                  121         121           121
# 9                  137         137           137
# 10                  15          15            15
# 11                  89          89            89
# 12                  41          41            41
# 13                  94          94            94
# 14                 123         123           123
# 15                 122         122           122
# 16                  59          59            59
# 17                 132         132           132
# 18                  87          87            87
# 19                   8           8             8
# 20                  58          58            58
# 21                  76          76            76
# 22                  23          23            23
# 23                  95          95            95
# 24                 115         115           115
# 25                 109         109           109
# 26                  14          14            14
# 27                  55          55            55
# 28                  44          44            44
# 29                  31          31            31
# 30                 144         144           144
# 31                  63          63            63
# 32                 164         164           164
# 33                 169         169           169

# %%
rows = []

for i3_file in tau_log[
    (tau_log["weights_calculated"] > 0) &
    (tau_log["weights_calculated"] < 200)
]["i3_file"]:
    counts = Counter()
    error = ""

    try:
        f = dataio.I3File(str(i3_file))

        while f.more():
            try:
                frame = f.pop_frame()
            except Exception as e:
                error = str(e)
                break

            counts[str(frame.Stop)] += 1

        f.close()

    except Exception as e:
        error = str(e)

    rows.append({
        "i3_file": i3_file,
        "DAQ": counts[str(icetray.I3Frame.DAQ)],
        "TrayInfo": counts[str(icetray.I3Frame.TrayInfo)],
        "Geometry": counts[str(icetray.I3Frame.Geometry)],
        "Calibration": counts[str(icetray.I3Frame.Calibration)],
        "DetectorStatus": counts[str(icetray.I3Frame.DetectorStatus)],
        "Physics": counts[str(icetray.I3Frame.Physics)],
        "error": error,
    })

frame_counts = pd.DataFrame(rows)
frame_counts
# Out:
#                                                                                                              i3_file  \
# 0   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1014.i3.zst
# 1   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1243.i3.zst
# 2   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1562.i3.zst
# 3   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2320.i3.zst
# 4   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3114.i3.zst
# 5   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3232.i3.zst
# 6   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3656.i3.zst
# 7   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3660.i3.zst
# 8   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3959.i3.zst
# 9   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4229.i3.zst
# 10  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4666.i3.zst
# 11  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5344.i3.zst
# 12  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5448.i3.zst
# 13  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5478.i3.zst
# 14  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5776.i3.zst
# 15  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5779.i3.zst
# 16  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5909.i3.zst
# 17  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6021.i3.zst
# 18  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6566.i3.zst
# 19  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6879.i3.zst
# 20  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7185.i3.zst
# 21  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7203.i3.zst
# 22  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7456.i3.zst
# 23  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7460.i3.zst
# 24  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7910.i3.zst
# 25  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8175.i3.zst
# 26  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8516.i3.zst
# 27  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8917.i3.zst
# 28  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9061.i3.zst
# 29  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9249.i3.zst
# 30  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9369.i3.zst
# 31  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9422.i3.zst
# 32  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9519.i3.zst
# 33  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9675.i3.zst
#
#     DAQ  TrayInfo  Geometry  Calibration  DetectorStatus  Physics  \
# 0   107         1         0            0               0        0
# 1   106         1         0            0               0        0
# 2   144         1         0            0               0        0
# 3    76         1         0            0               0        0
# 4    11         1         0            0               0        0
# 5   182         1         0            0               0        0
# 6   129         1         0            0               0        0
# 7    12         1         0            0               0        0
# 8   121         1         0            0               0        0
# 9   137         1         0            0               0        0
# 10   15         1         0            0               0        0
# 11   89         1         0            0               0        0
# 12   41         1         0            0               0        0
# 13   94         1         0            0               0        0
# 14  123         1         0            0               0        0
# 15  122         1         0            0               0        0
# 16   59         1         0            0               0        0
# 17  132         1         0            0               0        0
# 18   87         1         0            0               0        0
# 19    8         1         0            0               0        0
# 20   58         1         0            0               0        0
# 21   76         1         0            0               0        0
# 22   23         1         0            0               0        0
# 23   95         1         0            0               0        0
# 24  115         1         0            0               0        0
# 25  109         1         0            0               0        0
# 26   14         1         0            0               0        0
# 27   55         1         0            0               0        0
# 28   44         1         0            0               0        0
# 29   31         1         0            0               0        0
# 30  144         1         0            0               0        0
# 31   63         1         0            0               0        0
# 32  164         1         0            0               0        0
# 33  169         1         0            0               0        0
#
#                  error
# 0   input stream error
# 1   input stream error
# 2   input stream error
# 3   input stream error
# 4   input stream error
# 5   input stream error
# 6   input stream error
# 7   input stream error
# 8   input stream error
# 9   input stream error
# 10  input stream error
# 11  input stream error
# 12  input stream error
# 13  input stream error
# 14  input stream error
# 15  input stream error
# 16  input stream error
# 17  input stream error
# 18  input stream error
# 19  input stream error
# 20  input stream error
# 21  input stream error
# 22  input stream error
# 23  input stream error
# 24  input stream error
# 25  input stream error
# 26  input stream error
# 27  input stream error
# 28  input stream error
# 29  input stream error
# 30  input stream error
# 31  input stream error
# 32  input stream error
# 33  input stream error

# %%
tau_log[
    (tau_log["weights_calculated"] > 0) &
    (tau_log["weights_calculated"] < 200)
][["i3_file", "weights_calculated"]]
# Out:
#                                                                                                                i3_file  \
# 116   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1014.i3.zst
# 368   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1243.i3.zst
# 719   /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_1562.i3.zst
# 1553  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_2320.i3.zst
# 2426  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3114.i3.zst
# 2556  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3232.i3.zst
# 3022  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3656.i3.zst
# 3027  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3660.i3.zst
# 3351  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_3959.i3.zst
# 3648  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4229.i3.zst
# 4129  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_4666.i3.zst
# 4875  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5344.i3.zst
# 4989  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5448.i3.zst
# 5022  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5478.i3.zst
# 5350  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5776.i3.zst
# 5353  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5779.i3.zst
# 5496  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_5909.i3.zst
# 5620  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6021.i3.zst
# 6219  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6566.i3.zst
# 6563  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_6879.i3.zst
# 6900  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7185.i3.zst
# 6920  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7203.i3.zst
# 7198  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7456.i3.zst
# 7203  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7460.i3.zst
# 7698  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_7910.i3.zst
# 7989  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8175.i3.zst
# 8364  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8516.i3.zst
# 8805  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_8917.i3.zst
# 8964  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9061.i3.zst
# 9170  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9249.i3.zst
# 9302  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9369.i3.zst
# 9361  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9422.i3.zst
# 9467  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9519.i3.zst
# 9639  /project/6008051/pone_simulation/MC000004-nu_tau-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_9675.i3.zst
#
#       weights_calculated
# 116                  107
# 368                  106
# 719                  144
# 1553                  76
# 2426                  11
# 2556                 182
# 3022                 129
# 3027                  12
# 3351                 121
# 3648                 137
# 4129                  15
# 4875                  89
# 4989                  41
# 5022                  94
# 5350                 123
# 5353                 122
# 5496                  59
# 5620                 132
# 6219                  87
# 6563                   8
# 6900                  58
# 6920                  76
# 7198                  23
# 7203                  95
# 7698                 115
# 7989                 109
# 8364                  14
# 8805                  55
# 8964                  44
# 9170                  31
# 9302                 144
# 9361                  63
# 9467                 164
# 9639                 169

# %% [markdown]
# ## NC

# %%
len(nc_log[
    (nc_log["weights_calculated"] > 0) &
    (nc_log["weights_calculated"] < 200)
]
)
# Out:
# 12

# %%
nc_log[
    (nc_log["weights_calculated"] > 0) &
    (nc_log["weights_calculated"] < 200)
]
# Out:
#       batch_id  \
# 1350      2136
# 2038      2761
# 3348      3952
# 3613      4193
# 4075      4613
# 6519      6835
# 6785      7077
# 6902      7183
# 7763      7966
# 8252      8410
# 8626      8750
# 9622      9656
#
#                                                                                                                  lic_file  \
# 1350  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_2136.lic
# 2038  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_2761.lic
# 3348  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_3952.lic
# 3613  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_4193.lic
# 4075  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_4613.lic
# 6519  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_6835.lic
# 6785  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_7077.lic
# 6902  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_7183.lic
# 7763  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_7966.lic
# 8252  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_8410.lic
# 8626  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_8750.lic
# 9622  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/genCard_9656.lic
#
#                                                                                                                  i3_file  \
# 1350  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2136.i3.zst
# 2038  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2761.i3.zst
# 3348  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_3952.i3.zst
# 3613  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_4193.i3.zst
# 4075  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_4613.i3.zst
# 6519  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_6835.i3.zst
# 6785  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7077.i3.zst
# 6902  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7183.i3.zst
# 7763  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7966.i3.zst
# 8252  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_8410.i3.zst
# 8626  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_8750.i3.zst
# 9622  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_9656.i3.zst
#
#             status  \
# 1350  partially ok
# 2038  partially ok
# 3348  partially ok
# 3613  partially ok
# 4075  partially ok
# 6519  partially ok
# 6785  partially ok
# 6902  partially ok
# 7763  partially ok
# 8252  partially ok
# 8626  partially ok
# 9622  partially ok
#
#                                                                                                                                                                                                                                                                                         error  \
# 1350      i3 file problem: read error while reading EventProperties at event 55. 54 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 55: read error. 54 event weights were calculated before the problem. Error: input stream error
# 2038  i3 file problem: read error while reading EventProperties at event 121. 120 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 121: read error. 120 event weights were calculated before the problem. Error: input stream error
# 3348  i3 file problem: read error while reading EventProperties at event 152. 151 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 152: read error. 151 event weights were calculated before the problem. Error: input stream error
# 3613      i3 file problem: read error while reading EventProperties at event 52. 51 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 52: read error. 51 event weights were calculated before the problem. Error: input stream error
# 4075      i3 file problem: read error while reading EventProperties at event 72. 71 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 72: read error. 71 event weights were calculated before the problem. Error: input stream error
# 6519  i3 file problem: read error while reading EventProperties at event 112. 111 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 112: read error. 111 event weights were calculated before the problem. Error: input stream error
# 6785  i3 file problem: read error while reading EventProperties at event 121. 120 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 121: read error. 120 event weights were calculated before the problem. Error: input stream error
# 6902      i3 file problem: read error while reading EventProperties at event 31. 30 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 31: read error. 30 event weights were calculated before the problem. Error: input stream error
# 7763  i3 file problem: read error while reading EventProperties at event 185. 184 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 185: read error. 184 event weights were calculated before the problem. Error: input stream error
# 8252      i3 file problem: read error while reading EventProperties at event 51. 50 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 51: read error. 50 event weights were calculated before the problem. Error: input stream error
# 8626      i3 file problem: read error while reading EventProperties at event 55. 54 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 55: read error. 54 event weights were calculated before the problem. Error: input stream error
# 9622      i3 file problem: read error while reading EventProperties at event 74. 73 EventProperties entries were read before the problem. Error: input stream error | i3 file problem at event 74: read error. 73 event weights were calculated before the problem. Error: input stream error
#
#       i3_file_opened_ok  weights_calculated  duration_s
# 1350               True                  54    0.244127
# 2038               True                 120    0.876761
# 3348               True                 151    3.363825
# 3613               True                  51    0.547338
# 4075               True                  71    0.703567
# 6519               True                 111    0.721381
# 6785               True                 120    0.354110
# 6902               True                  30    0.479673
# 7763               True                 184    0.664011
# 8252               True                  50    0.881390
# 8626               True                  54    0.388335
# 9622               True                  73    0.569505

# %%
# weights_calculated comes from the LIW processing log CSV.
# truth_rows and max_event_id come from the produced LIW weights CSV, grouped by RunID.
nc_partial_compare_summary = (
    nc_weights.groupby("RunID", as_index=False)
    .agg(
        # Number of rows found in the LIW weights CSV for this RunID.
        truth_rows=("EventID", "size"),
        # Largest EventID found in the LIW weights CSV for this RunID.
        max_event_id=("EventID", "max"),
    )
    .rename(columns={"RunID": "batch_id"})
)

nc_partial_compare = (
    nc_log[
        (nc_log["weights_calculated"] > 0) &
        (nc_log["weights_calculated"] < 200)
    ][["batch_id", "i3_file", "weights_calculated"]]
    .merge(
        nc_partial_compare_summary,
        on="batch_id",
        how="left",
    )
    .sort_values("batch_id")
)

print("NC: weights_calculated == max_event_id")
print((nc_partial_compare["weights_calculated"] == nc_partial_compare["max_event_id"]).value_counts(dropna=False))
print()
print("NC: truth_rows == weights_calculated")
print((nc_partial_compare["truth_rows"] == nc_partial_compare["weights_calculated"]).value_counts(dropna=False))
print()

nc_partial_compare
# Out:
# NC: weights_calculated == max_event_id
# True    12
# Name: count, dtype: int64
#
# NC: truth_rows == weights_calculated
# True    12
# Name: count, dtype: int64
#     batch_id  \
# 0       2136
# 1       2761
# 2       3952
# 3       4193
# 4       4613
# 5       6835
# 6       7077
# 7       7183
# 8       7966
# 9       8410
# 10      8750
# 11      9656
#
#                                                                                                                i3_file  \
# 0   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2136.i3.zst
# 1   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2761.i3.zst
# 2   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_3952.i3.zst
# 3   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_4193.i3.zst
# 4   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_4613.i3.zst
# 5   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_6835.i3.zst
# 6   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7077.i3.zst
# 7   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7183.i3.zst
# 8   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7966.i3.zst
# 9   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_8410.i3.zst
# 10  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_8750.i3.zst
# 11  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_9656.i3.zst
#
#     weights_calculated  truth_rows  max_event_id
# 0                   54          54            54
# 1                  120         120           120
# 2                  151         151           151
# 3                   51          51            51
# 4                   71          71            71
# 5                  111         111           111
# 6                  120         120           120
# 7                   30          30            30
# 8                  184         184           184
# 9                   50          50            50
# 10                  54          54            54
# 11                  73          73            73

# %%
rows = []

for i3_file in nc_log[
    (nc_log["weights_calculated"] > 0) &
    (nc_log["weights_calculated"] < 200)
]["i3_file"]:
    counts = Counter()
    error = ""

    try:
        f = dataio.I3File(str(i3_file))

        while f.more():
            try:
                frame = f.pop_frame()
            except Exception as e:
                error = str(e)
                break

            counts[str(frame.Stop)] += 1

        f.close()

    except Exception as e:
        error = str(e)

    rows.append({
        "i3_file": i3_file,
        "DAQ": counts[str(icetray.I3Frame.DAQ)],
        "TrayInfo": counts[str(icetray.I3Frame.TrayInfo)],
        "Geometry": counts[str(icetray.I3Frame.Geometry)],
        "Calibration": counts[str(icetray.I3Frame.Calibration)],
        "DetectorStatus": counts[str(icetray.I3Frame.DetectorStatus)],
        "Physics": counts[str(icetray.I3Frame.Physics)],
        "error": error,
    })

frame_counts = pd.DataFrame(rows)
frame_counts
# Out:
#                                                                                                                i3_file  \
# 0   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2136.i3.zst
# 1   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_2761.i3.zst
# 2   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_3952.i3.zst
# 3   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_4193.i3.zst
# 4   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_4613.i3.zst
# 5   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_6835.i3.zst
# 6   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7077.i3.zst
# 7   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7183.i3.zst
# 8   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_7966.i3.zst
# 9   /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_8410.i3.zst
# 10  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_8750.i3.zst
# 11  /project/6008051/pone_simulation/MC000005-nu_NC-2_7-LeptonInjector_PROPOSAL_clsim_NC-v10/Generator/gen_9656.i3.zst
#
#     DAQ  TrayInfo  Geometry  Calibration  DetectorStatus  Physics  \
# 0    54         1         0            0               0        0
# 1   120         1         0            0               0        0
# 2   151         1         0            0               0        0
# 3    51         1         0            0               0        0
# 4    71         1         0            0               0        0
# 5   111         1         0            0               0        0
# 6   120         1         0            0               0        0
# 7    30         1         0            0               0        0
# 8   184         1         0            0               0        0
# 9    50         1         0            0               0        0
# 10   54         1         0            0               0        0
# 11   73         1         0            0               0        0
#
#                  error
# 0   input stream error
# 1   input stream error
# 2   input stream error
# 3   input stream error
# 4   input stream error
# 5   input stream error
# 6   input stream error
# 7   input stream error
# 8   input stream error
# 9   input stream error
# 10  input stream error
# 11  input stream error
