# %%
from icecube import dataio, icetray
import pandas as pd
from icecube import LeptonInjector # for EventProperties
from icecube import simclasses # for MMCTrackList

# %%
path = "/home/kbas/scratch/Spring2026MC/Full_Geometry/Muon_PMT_Response/muon_33939527_gen_001.i3.gz"
path = "/project/6008051/pone_simulation/MC000009-nu_e-2_6-LeptonInjector_PROPOSAL_clsim-v17.1/Generator/33996141/gen_008.i3.zst"
data_file = dataio.I3File(path)

# %%
data_file.pop_frame()
data_file.pop_frame()
frame = data_file.pop_frame()


print(frame)
print(type(frame))
# Out:
# [ I3Frame  (DAQ):
#   'Accepted_PulseMap' [DAQ] ==> I3Map<OMKey, vector<I3RecoPulse> > (26481)
#   'EventProperties' [DAQ] ==> LeptonInjector::BasicEventProperties (140)
#   'I3EventHeader' [DAQ] ==> I3EventHeader (99)
#   'I3MCTree' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, i3hash<I3ParticleID> > (422)
#   'I3MCTree_RNGState' [DAQ] ==> I3GSLRandomServiceState (87)
#   'I3Photons' [DAQ] ==> I3Map<ModuleKey, I3Vector<I3CompressedPhoton> > (2056439)
#   'LeptonInjectorProperties' [Simulation] ==> LeptonInjector::VolumeInjectionConfiguration (2376162)
#   'MMCTrackList' [DAQ] ==> I3Vector<I3MMCTrack> (40)
#   'Noise_Dark' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (460888)
#   'Noise_K40' [DAQ] ==> I3Map<OMKey, vector<I3MCPE> > (1418857)
# ]
#
# <class 'icecube._icetray.I3Frame'>

# %%
print(frame['Accepted_PulseMap'])
# Out:
# [OMKey(415,11,7) => [[I3RecoPulse:
#              Time : 607.659
#            Charge : 1
#             Width : nan
#             Flags :
# ]],
# OMKey(415,12,12) => [[I3RecoPulse:
#              Time : 566.458
#            Charge : 1
#             Width : nan
#             Flags :
# ]],
# OMKey(415,12,15) => [[I3RecoPulse:
#              Time : 561.249
#            Charge : 1
#             Width : nan
#             Flags :
# ]],
# OMKey(416,11,8) => [[I3RecoPulse:
#              Time : 604.886
#            Charge : 1
#             Width : nan
#             Flags :
# ]],
# OMKey(452,11,7) => [[I3RecoPulse:
#              Time : 449.959
#            Charge : 1
#             Width : nan
#             Flags :
# ]],
# OMKey(452,11,16) => [[I3RecoPulse:
#              Time : 437.806
#            Charge : 1
#             Width : nan
#             Flags :
# ]],
# OMKey(453,12,14) => [[I3RecoPulse:
#              Time : 513.24
#            Charge : 1
#             Width : nan
# ...
