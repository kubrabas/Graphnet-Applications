# %%
import pandas as pd
from IPython.display import display

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # PMT

# %%
csv_path_pmt = "/project/def-nahee/kbas/Graphnet-Applications/Playground/Datasets/summary_pmt.csv"
csv_path_i3 = "/project/def-nahee/kbas/Graphnet-Applications/Playground/Datasets/summary_i3.csv"

# %%
df_pmt = pd.read_csv(csv_path_pmt)

display(
    df_pmt.head(5).style.set_table_attributes(
        'style="display:block; overflow-x:auto; max-width:100%; white-space:nowrap;"'
    )
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac950" style="display:block; overflow-x:auto; max-width:100%; white-space:nowrap;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac950_level0_col0" class="col_heading level0 col0" >section</th>
#       <th id="T_ac950_level0_col1" class="col_heading level0 col1" >file_path</th>
#       <th id="T_ac950_level0_col2" class="col_heading level0 col2" >file_format</th>
#       <th id="T_ac950_level0_col3" class="col_heading level0 col3" >frames_with_EPS</th>
#       <th id="T_ac950_level0_col4" class="col_heading level0 col4" >frames_with_nonempty_EPS</th>
#       <th id="T_ac950_level0_col5" class="col_heading level0 col5" >unique_string_id_count_EPS</th>
#       <th id="T_ac950_level0_col6" class="col_heading level0 col6" >total_pulse_count_EPS</th>
#       <th id="T_ac950_level0_col7" class="col_heading level0 col7" >avg_pulses_per_nonempty_frame_EPS</th>
#       <th id="T_ac950_level0_col8" class="col_heading level0 col8" >frames_with_EPS_NONOISE</th>
#       <th id="T_ac950_level0_col9" class="col_heading level0 col9" >frames_with_nonempty_EPS_NONOISE</th>
#       <th id="T_ac950_level0_col10" class="col_heading level0 col10" >unique_string_id_count_EPS_NONOISE</th>
#       <th id="T_ac950_level0_col11" class="col_heading level0 col11" >total_pulse_count_EPS_NONOISE</th>
#       <th id="T_ac950_level0_col12" class="col_heading level0 col12" >avg_pulses_per_nonempty_frame_EPS_NONOISE</th>
#       <th id="T_ac950_level0_col13" class="col_heading level0 col13" >status</th>
#       <th id="T_ac950_level0_col14" class="col_heading level0 col14" >error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac950_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac950_row0_col0" class="data row0 col0" >340String/Electron_PMT_Response</td>
#       <td id="T_ac950_row0_col1" class="data row0 col1" >/scratch/kbas/340_string/Electron_PMT_Response/electron_batch_000.i3.gz</td>
#       <td id="T_ac950_row0_col2" class="data row0 col2" >i3.gz</td>
#       <td id="T_ac950_row0_col3" class="data row0 col3" >20</td>
#       <td id="T_ac950_row0_col4" class="data row0 col4" >20</td>
#       <td id="T_ac950_row0_col5" class="data row0 col5" >340</td>
#       <td id="T_ac950_row0_col6" class="data row0 col6" >90362</td>
#       <td id="T_ac950_row0_col7" class="data row0 col7" >4518.100000</td>
#       <td id="T_ac950_row0_col8" class="data row0 col8" >20</td>
#       <td id="T_ac950_row0_col9" class="data row0 col9" >20</td>
#       <td id="T_ac950_row0_col10" class="data row0 col10" >90</td>
#       <td id="T_ac950_row0_col11" class="data row0 col11" >1575</td>
#       <td id="T_ac950_row0_col12" class="data row0 col12" >78.750000</td>
#       <td id="T_ac950_row0_col13" class="data row0 col13" >ok</td>
#       <td id="T_ac950_row0_col14" class="data row0 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ac950_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac950_row1_col0" class="data row1 col0" >340String/Electron_PMT_Response</td>
#       <td id="T_ac950_row1_col1" class="data row1 col1" >/scratch/kbas/340_string/Electron_PMT_Response/electron_batch_001.i3.gz</td>
#       <td id="T_ac950_row1_col2" class="data row1 col2" >i3.gz</td>
#       <td id="T_ac950_row1_col3" class="data row1 col3" >22</td>
#       <td id="T_ac950_row1_col4" class="data row1 col4" >22</td>
#       <td id="T_ac950_row1_col5" class="data row1 col5" >340</td>
#       <td id="T_ac950_row1_col6" class="data row1 col6" >98716</td>
#       <td id="T_ac950_row1_col7" class="data row1 col7" >4487.090909</td>
#       <td id="T_ac950_row1_col8" class="data row1 col8" >22</td>
#       <td id="T_ac950_row1_col9" class="data row1 col9" >22</td>
#       <td id="T_ac950_row1_col10" class="data row1 col10" >79</td>
#       <td id="T_ac950_row1_col11" class="data row1 col11" >1327</td>
#       <td id="T_ac950_row1_col12" class="data row1 col12" >60.318182</td>
#       <td id="T_ac950_row1_col13" class="data row1 col13" >ok</td>
#       <td id="T_ac950_row1_col14" class="data row1 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ac950_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac950_row2_col0" class="data row2 col0" >340String/Electron_PMT_Response</td>
#       <td id="T_ac950_row2_col1" class="data row2 col1" >/scratch/kbas/340_string/Electron_PMT_Response/electron_batch_002.i3.gz</td>
#       <td id="T_ac950_row2_col2" class="data row2 col2" >i3.gz</td>
#       <td id="T_ac950_row2_col3" class="data row2 col3" >26</td>
#       <td id="T_ac950_row2_col4" class="data row2 col4" >26</td>
#       <td id="T_ac950_row2_col5" class="data row2 col5" >340</td>
#       <td id="T_ac950_row2_col6" class="data row2 col6" >116972</td>
#       <td id="T_ac950_row2_col7" class="data row2 col7" >4498.923077</td>
#       <td id="T_ac950_row2_col8" class="data row2 col8" >26</td>
#       <td id="T_ac950_row2_col9" class="data row2 col9" >26</td>
#       <td id="T_ac950_row2_col10" class="data row2 col10" >95</td>
#       <td id="T_ac950_row2_col11" class="data row2 col11" >922</td>
#       <td id="T_ac950_row2_col12" class="data row2 col12" >35.461538</td>
#       <td id="T_ac950_row2_col13" class="data row2 col13" >ok</td>
#       <td id="T_ac950_row2_col14" class="data row2 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ac950_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac950_row3_col0" class="data row3 col0" >340String/Electron_PMT_Response</td>
#       <td id="T_ac950_row3_col1" class="data row3 col1" >/scratch/kbas/340_string/Electron_PMT_Response/electron_batch_003.i3.gz</td>
#       <td id="T_ac950_row3_col2" class="data row3 col2" >i3.gz</td>
#       <td id="T_ac950_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_ac950_row3_col4" class="data row3 col4" >32</td>
#       <td id="T_ac950_row3_col5" class="data row3 col5" >340</td>
#       <td id="T_ac950_row3_col6" class="data row3 col6" >143599</td>
#       <td id="T_ac950_row3_col7" class="data row3 col7" >4487.468750</td>
#       <td id="T_ac950_row3_col8" class="data row3 col8" >32</td>
#       <td id="T_ac950_row3_col9" class="data row3 col9" >32</td>
#       <td id="T_ac950_row3_col10" class="data row3 col10" >134</td>
#       <td id="T_ac950_row3_col11" class="data row3 col11" >2661</td>
#       <td id="T_ac950_row3_col12" class="data row3 col12" >83.156250</td>
#       <td id="T_ac950_row3_col13" class="data row3 col13" >ok</td>
#       <td id="T_ac950_row3_col14" class="data row3 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ac950_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac950_row4_col0" class="data row4 col0" >340String/Electron_PMT_Response</td>
#       <td id="T_ac950_row4_col1" class="data row4 col1" >/scratch/kbas/340_string/Electron_PMT_Response/electron_batch_004.i3.gz</td>
#       <td id="T_ac950_row4_col2" class="data row4 col2" >i3.gz</td>
#       <td id="T_ac950_row4_col3" class="data row4 col3" >23</td>
#       <td id="T_ac950_row4_col4" class="data row4 col4" >23</td>
#       <td id="T_ac950_row4_col5" class="data row4 col5" >340</td>
#       <td id="T_ac950_row4_col6" class="data row4 col6" >97757</td>
#       <td id="T_ac950_row4_col7" class="data row4 col7" >4250.304348</td>
#       <td id="T_ac950_row4_col8" class="data row4 col8" >23</td>
#       <td id="T_ac950_row4_col9" class="data row4 col9" >21</td>
#       <td id="T_ac950_row4_col10" class="data row4 col10" >75</td>
#       <td id="T_ac950_row4_col11" class="data row4 col11" >927</td>
#       <td id="T_ac950_row4_col12" class="data row4 col12" >44.142857</td>
#       <td id="T_ac950_row4_col13" class="data row4 col13" >ok</td>
#       <td id="T_ac950_row4_col14" class="data row4 col14" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### chek if  "frames_with_EPS", "frames_with_nonempty_EPS", "frames_with_EPS_NONOISE" are all same:

# %%
cols = [
    "frames_with_EPS",
    "frames_with_nonempty_EPS",
    "frames_with_EPS_NONOISE",

]

missing = [c for c in cols if c not in df_pmt.columns]
if missing:
    raise ValueError(f"Missing columns: {missing}")

all_same_mask = df_pmt[cols].nunique(axis=1).eq(1)
print(f"Rows where all 3 are identical: {all_same_mask.sum()} / {len(df_pmt)}")
# Out:
# Rows where all 3 are identical: 53390 / 53390

# %% [markdown]
# #### chek unique "frames_with_EPS", "frames_with_nonempty_EPS", "frames_with_EPS_NONOISE", frames_with_nonempty_EPS_NONOISE per group, and count total_pulse_count_EPS_NONOISE

# %%
cols_sum = [
    "frames_with_EPS",
    "frames_with_nonempty_EPS",
    "frames_with_EPS_NONOISE",
    "frames_with_nonempty_EPS_NONOISE",
    "total_pulse_count_EPS_NONOISE",
]

for c in cols_sum:
    df_pmt[c] = pd.to_numeric(df_pmt[c], errors="coerce").fillna(0)

g = (
    df_pmt.groupby("section", as_index=False)[cols_sum]
      .sum()
)

display(g)
# Out:
#                            section  frames_with_EPS  frames_with_nonempty_EPS  \
# 0  340String/Electron_PMT_Response           164753                    164753
# 1      340String/Muon_PMT_Response           409563                    409563
# 2       340String/Tau_PMT_Response           241161                    241161
# 3   98String/Electron_PMT_Response            60580                     60580
# 4       98String/Muon_PMT_Response           202987                    202987
# 5        98String/Tau_PMT_Response            90293                     90293
#
#    frames_with_EPS_NONOISE  frames_with_nonempty_EPS_NONOISE  \
# 0                   164753                            161242
# 1                   409563                            404205
# 2                   241161                            234606
# 3                    60580                             58462
# 4                   202987                            198800
# 5                    90293                             87107
#
#    total_pulse_count_EPS_NONOISE
# 0                       11820398
# 1                       60225940
# 2                       16632106
# 3                        3531325
# 4                       18363738
# 5                        4965595

# %% [markdown]
# # I3

# %%
df_i3 = pd.read_csv(csv_path_i3)


display(
    df_i3.head(5).style.set_table_attributes(
        'style="display:block; overflow-x:auto; max-width:100%; white-space:nowrap;"'
    )
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e509" style="display:block; overflow-x:auto; max-width:100%; white-space:nowrap;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e509_level0_col0" class="col_heading level0 col0" >section</th>
#       <th id="T_6e509_level0_col1" class="col_heading level0 col1" >file_path</th>
#       <th id="T_6e509_level0_col2" class="col_heading level0 col2" >file_format</th>
#       <th id="T_6e509_level0_col3" class="col_heading level0 col3" >data_format</th>
#       <th id="T_6e509_level0_col4" class="col_heading level0 col4" >frames_with_I3Photons</th>
#       <th id="T_6e509_level0_col5" class="col_heading level0 col5" >frames_with_nonempty_I3Photons</th>
#       <th id="T_6e509_level0_col6" class="col_heading level0 col6" >unique_string_id_count</th>
#       <th id="T_6e509_level0_col7" class="col_heading level0 col7" >total_photon_count</th>
#       <th id="T_6e509_level0_col8" class="col_heading level0 col8" >avg_photons_per_nonempty_frame</th>
#       <th id="T_6e509_level0_col9" class="col_heading level0 col9" >avg_modulekeys_per_nonempty_frame</th>
#       <th id="T_6e509_level0_col10" class="col_heading level0 col10" >status</th>
#       <th id="T_6e509_level0_col11" class="col_heading level0 col11" >error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e509_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e509_row0_col0" class="data row0 col0" >340string/Electron_I3Photons</td>
#       <td id="T_6e509_row0_col1" class="data row0 col1" >/project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_000.i3.zst</td>
#       <td id="T_6e509_row0_col2" class="data row0 col2" >i3.zst</td>
#       <td id="T_6e509_row0_col3" class="data row0 col3" >I3Photons</td>
#       <td id="T_6e509_row0_col4" class="data row0 col4" >200</td>
#       <td id="T_6e509_row0_col5" class="data row0 col5" >34</td>
#       <td id="T_6e509_row0_col6" class="data row0 col6" >203</td>
#       <td id="T_6e509_row0_col7" class="data row0 col7" >352387</td>
#       <td id="T_6e509_row0_col8" class="data row0 col8" >10364.323529</td>
#       <td id="T_6e509_row0_col9" class="data row0 col9" >24.647059</td>
#       <td id="T_6e509_row0_col10" class="data row0 col10" >ok</td>
#       <td id="T_6e509_row0_col11" class="data row0 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6e509_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e509_row1_col0" class="data row1 col0" >340string/Electron_I3Photons</td>
#       <td id="T_6e509_row1_col1" class="data row1 col1" >/project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_001.i3.zst</td>
#       <td id="T_6e509_row1_col2" class="data row1 col2" >i3.zst</td>
#       <td id="T_6e509_row1_col3" class="data row1 col3" >I3Photons</td>
#       <td id="T_6e509_row1_col4" class="data row1 col4" >200</td>
#       <td id="T_6e509_row1_col5" class="data row1 col5" >38</td>
#       <td id="T_6e509_row1_col6" class="data row1 col6" >183</td>
#       <td id="T_6e509_row1_col7" class="data row1 col7" >154703</td>
#       <td id="T_6e509_row1_col8" class="data row1 col8" >4071.131579</td>
#       <td id="T_6e509_row1_col9" class="data row1 col9" >23.710526</td>
#       <td id="T_6e509_row1_col10" class="data row1 col10" >ok</td>
#       <td id="T_6e509_row1_col11" class="data row1 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6e509_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e509_row2_col0" class="data row2 col0" >340string/Electron_I3Photons</td>
#       <td id="T_6e509_row2_col1" class="data row2 col1" >/project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_002.i3.zst</td>
#       <td id="T_6e509_row2_col2" class="data row2 col2" >i3.zst</td>
#       <td id="T_6e509_row2_col3" class="data row2 col3" >I3Photons</td>
#       <td id="T_6e509_row2_col4" class="data row2 col4" >200</td>
#       <td id="T_6e509_row2_col5" class="data row2 col5" >40</td>
#       <td id="T_6e509_row2_col6" class="data row2 col6" >223</td>
#       <td id="T_6e509_row2_col7" class="data row2 col7" >113336</td>
#       <td id="T_6e509_row2_col8" class="data row2 col8" >2833.400000</td>
#       <td id="T_6e509_row2_col9" class="data row2 col9" >20.600000</td>
#       <td id="T_6e509_row2_col10" class="data row2 col10" >ok</td>
#       <td id="T_6e509_row2_col11" class="data row2 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6e509_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e509_row3_col0" class="data row3 col0" >340string/Electron_I3Photons</td>
#       <td id="T_6e509_row3_col1" class="data row3 col1" >/project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_003.i3.zst</td>
#       <td id="T_6e509_row3_col2" class="data row3 col2" >i3.zst</td>
#       <td id="T_6e509_row3_col3" class="data row3 col3" >I3Photons</td>
#       <td id="T_6e509_row3_col4" class="data row3 col4" >200</td>
#       <td id="T_6e509_row3_col5" class="data row3 col5" >48</td>
#       <td id="T_6e509_row3_col6" class="data row3 col6" >241</td>
#       <td id="T_6e509_row3_col7" class="data row3 col7" >833139</td>
#       <td id="T_6e509_row3_col8" class="data row3 col8" >17357.062500</td>
#       <td id="T_6e509_row3_col9" class="data row3 col9" >29.520833</td>
#       <td id="T_6e509_row3_col10" class="data row3 col10" >ok</td>
#       <td id="T_6e509_row3_col11" class="data row3 col11" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6e509_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e509_row4_col0" class="data row4 col0" >340string/Electron_I3Photons</td>
#       <td id="T_6e509_row4_col1" class="data row4 col1" >/project/6008051/pone_simulation/MC000003-nu_e-2_7-LeptonInjector_PROPOSAL_clsim-v10/Generator/gen_004.i3.zst</td>
#       <td id="T_6e509_row4_col2" class="data row4 col2" >i3.zst</td>
#       <td id="T_6e509_row4_col3" class="data row4 col3" >I3Photons</td>
#       <td id="T_6e509_row4_col4" class="data row4 col4" >200</td>
#       <td id="T_6e509_row4_col5" class="data row4 col5" >44</td>
#       <td id="T_6e509_row4_col6" class="data row4 col6" >211</td>
#       <td id="T_6e509_row4_col7" class="data row4 col7" >129280</td>
#       <td id="T_6e509_row4_col8" class="data row4 col8" >2938.181818</td>
#       <td id="T_6e509_row4_col9" class="data row4 col9" >18.727273</td>
#       <td id="T_6e509_row4_col10" class="data row4 col10" >ok</td>
#       <td id="T_6e509_row4_col11" class="data row4 col11" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# groupby section: sums + max
cols_sum = ["frames_with_nonempty_I3Photons", "frames_with_I3Photons"]
col_max = "unique_string_id_count"

# sayısala çevir (garanti)
for c in cols_sum + [col_max]:
    df_i3[c] = pd.to_numeric(df_i3[c], errors="coerce")

g = (
    df_i3.groupby("section", as_index=False)
      .agg({
          "frames_with_I3Photons": "sum",
          "frames_with_nonempty_I3Photons": "sum",
          "unique_string_id_count": "max",
      })
)

display(
    g.style.set_table_attributes(
        'style="display:block; overflow-x:auto; max-width:100%; white-space:nowrap;"'
    )
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0a3ae" style="display:block; overflow-x:auto; max-width:100%; white-space:nowrap;">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a3ae_level0_col0" class="col_heading level0 col0" >section</th>
#       <th id="T_0a3ae_level0_col1" class="col_heading level0 col1" >frames_with_I3Photons</th>
#       <th id="T_0a3ae_level0_col2" class="col_heading level0 col2" >frames_with_nonempty_I3Photons</th>
#       <th id="T_0a3ae_level0_col3" class="col_heading level0 col3" >unique_string_id_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a3ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a3ae_row0_col0" class="data row0 col0" >340string/Electron_I3Photons</td>
#       <td id="T_0a3ae_row0_col1" class="data row0 col1" >1368600</td>
#       <td id="T_0a3ae_row0_col2" class="data row0 col2" >268420</td>
#       <td id="T_0a3ae_row0_col3" class="data row0 col3" >309</td>
#     </tr>
#     <tr>
#       <th id="T_0a3ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a3ae_row1_col0" class="data row1 col0" >340string/Muon_I3Photons</td>
#       <td id="T_0a3ae_row1_col1" class="data row1 col1" >1926560</td>
#       <td id="T_0a3ae_row1_col2" class="data row1 col2" >593674</td>
#       <td id="T_0a3ae_row1_col3" class="data row1 col3" >340</td>
#     </tr>
#     <tr>
#       <th id="T_0a3ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a3ae_row2_col0" class="data row2 col0" >340string/Tau_I3Photons</td>
#       <td id="T_0a3ae_row2_col1" class="data row2 col1" >1992200</td>
#       <td id="T_0a3ae_row2_col2" class="data row2 col2" >396801</td>
#       <td id="T_0a3ae_row2_col3" class="data row2 col3" >313</td>
#     </tr>
#     <tr>
#       <th id="T_0a3ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a3ae_row3_col0" class="data row3 col0" >98String/Electron_I3Photons</td>
#       <td id="T_0a3ae_row3_col1" class="data row3 col1" >138619</td>
#       <td id="T_0a3ae_row3_col2" class="data row3 col2" >138619</td>
#       <td id="T_0a3ae_row3_col3" class="data row3 col3" >101</td>
#     </tr>
#     <tr>
#       <th id="T_0a3ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a3ae_row4_col0" class="data row4 col0" >98String/Muon_I3Photons</td>
#       <td id="T_0a3ae_row4_col1" class="data row4 col1" >344350</td>
#       <td id="T_0a3ae_row4_col2" class="data row4 col2" >344350</td>
#       <td id="T_0a3ae_row4_col3" class="data row4 col3" >102</td>
#     </tr>
#     <tr>
#       <th id="T_0a3ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0a3ae_row5_col0" class="data row5 col0" >98String/Tau_I3Photons</td>
#       <td id="T_0a3ae_row5_col1" class="data row5 col1" >206721</td>
#       <td id="T_0a3ae_row5_col2" class="data row5 col2" >206721</td>
#       <td id="T_0a3ae_row5_col3" class="data row5 col3" >100</td>
#     </tr>
#   </tbody>
# </table>
