# %% [markdown]
# On the cluster, there are two GCD files that I suspect might correspond to the data under the directory `"/project/6008051/pone_simulation/MC10-000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim/Photon"`
#
# 1. `"/project/6008051/pone_simulation/GCD_Library/PONE_800mGrid.i3.gz"`
# - 340 string, 20 OM, 16 PMT
# 2. `"/project/6008051/pone_simulation/GCD_Library/PONE_800mGrid_x4Density.i3.gz"`
# - 1375 strings, 40 OM, 16 PMT
#
# `"/project/6008051/pone_simulation/MC10-000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim/Photon"`
# - I checked one of the batches from the data under this directory: max string id in this batch is 340. Therefore, I believe the first GCD file is the correct one.
# - There are 9817 batches in this directory
# - Question: Do all batches have 201 frame? How many of them are DAQ frames?
# - ToDo: The confluence page for this data has wrong path for the GCD, I guess. Contact Caleb
