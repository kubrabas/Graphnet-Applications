# %%
import os
from icecube import icetray, dataio, dataclasses, simclasses
from collections import Counter

# %%
icetray.I3Logger.global_logger = icetray.I3NullLogger()

# %%
raw_file_example = "/project/6008051/pone_simulation/MC10-000002-nu_mu-2_7-LeptonInjector-PROPOSAL-clsim/Photon/cls_4910.i3"

# %%
print("exists:", os.path.exists(raw_file_example))
print("size (MB):", os.path.getsize(raw_file_example)/1e6 if os.path.exists(raw_file_example) else None)
# Out:
# exists: True
# size (MB): 2836.732093

# %%
f = dataio.I3File(raw_file_example, "r")

# %%
f

# %%
print(f)
# Out:
# <icecube._dataio.I3File object at 0x14c7ce37e480>

# %%
counts = Counter()
total = 0

while f.more():
    frame = f.pop_frame()
    total += 1
    counts[str(frame.Stop)] += 1

print("total frames:", total)
print("by Stop:")
for k, v in counts.most_common():
    print(f"  {k}: {v}")
# Out:
# total frames: 201
# by Stop:
#   DAQ: 200
#   TrayInfo: 1

# %%
f = dataio.I3File(raw_file_example, "r")

i = 0
tray_indices = []

while f.more():
    frame = f.pop_frame()
    if frame.Stop == icetray.I3Frame.TrayInfo:
        tray_indices.append(i)
    i += 1

print("TrayInfo indices (0-based):", tray_indices)
# Out:
# TrayInfo indices (0-based): [0]

# %%
f = dataio.I3File(raw_file_example, "r")
frame0 = f.pop_frame()  # TrayInfo

for k in frame0.keys():
    v = frame0[k]
    print("KEY:", k)
    print("  type:", type(v))
    print("  value:", v)
# Out:
# KEY: 2025-10-02T15:01:23.012653
#   type: <class 'icecube._icetray.I3TrayInfo'>
#   value: ============================= configuration ==============================
#       Icetray run started:  Thu Oct  2 08:01:23 2025
#                   on host:  fc11017 (Linux-5.14.0-427.37.1.el9_4.x86_64/x86_64/gcc-11.4.0)
#                   as user:  cmiller
#           and gcc version:  11.4.0
#                   svn url:
#              svn revision:  0
#
# ===========================   svn:externals   ============================
#
# =============================   services    ==============================
# =============================    modules    ==============================
# reader (I3Reader)
#   DropBuffers
#     Description :  Tell I3Frames not to cache buffers of serialized frameobject data (this saves memory at the expense of processing speed and the ability to passthru unknown frame objects)
#     Default     :  False
#     Configured  :  None
#
#   Filename
#     Description :  Filename to read.  Use either this or Filenamelist, not both.
#     Default     :  ''
#     Configured  :  None
#
#   FilenameList
#     Description :  List of files to read, *IN SORTED ORDER*
#     Default     :  []
#     Configured  :  ['/localscratch/cmiller.6262968.0/gen_4910.i3']
#
#   SkipKeys
#     Description :  Don't load frame objects with these keys
#     Default     :  []
#     Configured  :  None
#
#
#
# makeCLSimHits_decomposeGeometry (I3GeometryDecomposer)
#   DeleteI3Geometry
#     Description :  Get rid of the original I3Geometry object.
#     Default     :  False
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  '<function I3CLSimMakePhotonsWithServer.<locals>.<lambda> at 0x1497a1f832e0>'
#
#
#
# makeCLSimHits_makePhotons (I3PhotonPropagationClientModule)
#   ClosestDOMDistanceCutoff
#     Description :  Do not even start light from sources that do not have any DOMs closer to
# to them than this distance.
#     Default     :  300.0
#     Configured  :  None
#
#   CosmicEventGenerator
#     Description :  Instance of I3CosmicEventGenerator to
#     Default     :  None
#     Configured  :  None
#
#   FlasherPulseSeriesName
#     Description :  Name of the I3FlasherPulseSeries frame object. Flasher pulses will be read from this object.
# Set this to the empty string to disable flashers.
#     Default     :  ''
#     Configured  :  ''
#
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  '<function <lambda> at 0x1497acbb2830>'
#
#   IgnoreMuons
#     Description :  If set to True, muons will not be propagated.
#     Default     :  False
#     Configured  :  None
#
#   IgnorePhotonPropagatorErrors
#     Description :  Continue processing frames even after the photon propagator encounters an error
#     Default     :  False
#     Configured  :  None
#
#   IgnoreSubdetectors
#     Description :  Ignore all OMKeys with these subdetector names
#     Default     :  []
#     Configured  :  ['IceTop']
#
#   MCPEGenerator
#     Description :  Instance of I3CLSimPhotonToMCPEConverter
#     Default     :  None
#     Configured  :  None
#
#   MCPESeriesMapName
#     Description :  Name of the I3MCPESeriesMap frame object that will be written to the frame.
#     Default     :  ''
#     Configured  :  ''
#
#   MCTreeName
#     Description :  Name of the I3MCTree frame object. All particles except neutrinos will be read from this tree.
#     Default     :  'I3MCTree'
#     Configured  :  'I3MCTree_postprop'
#
#   OMKeyMaskName
#     Description :  Name of a I3VectorOMKey or I3VectorModuleKey with masked DOMs. DOMs in this list will not record I3Photons.
#     Default     :  ''
#     Configured  :  None
#
#   PhotonHistoryEntries
#     Description :  Sets the number of scattering step positions that are saved for a photon hitting
# a DOM. The last N photons are saved if there are more scattering points than available entries.
#     Default     :  0
#     Configured  :  0
#
#   PhotonSeriesMapName
#     Description :  Name of the I3CLSimPhotonSeriesMap frame object that will be written to the frame.
#     Default     :  'PropagatedPhotons'
#     Configured  :  'I3Photons'
#
#   ServerAddress
#     Description :  Address of an I3PhotonPropagationServer instance
#     Default     :  ''
#     Configured  :  'tcp://127.0.0.1:34613'
#
#   StatisticsName
#     Description :  Collect statistics in this frame object (e.g. number of photons generated or reaching the DOMs)
#     Default     :  ''
#     Configured  :  None
#
#   StepGenerator
#     Description :  Instance of I3LightSourceToStepConverterAsync
#     Default     :  None
#     Configured  :  '<icecube._sim_services.I3LightSourceToStepConverterAsync object at 0x1497a20212b0>'
#
#   WorkOnTheseStops
#     Description :  Work on MCTrees found in the stream types ("stops") specified in this list
#     Default     :  [icetray.I3Frame.DAQ]
#     Configured  :  None
#
#
#
# GatherStatistics_0000 (icecube.clsim.traysegments.I3CLSimMakePhotons.GatherStatistics)
# (No parameters)
#
#
# writer (I3Writer)
#   CompressionLevel
#     Description :  0 == default compression, 1 == best speed, 9 == best compression (6 by default)
#     Default     :  0
#     Configured  :  None
#
#   DropOrphanStreams
#     Description :  Vector of I3Frame.Stream types to drop if they are not followed by other frames. Default: drop nothing
#     Default     :  []
#     Configured  :  None
#
#   Filename
#     Description :  The file we'll write to. If it ends with .gz and no CompressionLevel is specified, it will be gzipped at gzip's default compression level.  In the I3MultiWriter this string must contain a %u printf formatting character.  (Try %04u if you're writing < 10000 files)
#     Default     :  ''
#     Configured  :  '/localscratch/cmiller.6262968.0/cls_4910.i3'
#
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  None
#
#   SkipKeys
#     Description :  Don't write keys that match any of the regular expressions in this vector
#     Default     :  []
#     Configured  :  None
#
#   Streams
#     Description :  Vector of I3Frame.Stream types that we should write.  Those that do not appear here will be skipped. Default: all streams enabled.
#     Default     :  []
#     Configured  :  [icetray.I3Frame.TrayInfo, icetray.I3Frame.Simulation, icetray.I3Frame.DAQ]
#
#
#
# adios (TrashCan)
# (No parameters)
#
#
# ==========================================================================
#
# KEY: 2025-09-22T18:21:58.101188
#   type: <class 'icecube._icetray.I3TrayInfo'>
#   value: ============================= configuration ==============================
#       Icetray run started:  Mon Sep 22 11:21:58 2025
#                   on host:  fc30559 (Linux-5.14.0-427.37.1.el9_4.x86_64/x86_64/gcc-11.4.0)
#                   as user:  cmiller
#           and gcc version:  11.4.0
#                   svn url:
#              svn revision:  0
#
# ===========================   svn:externals   ============================
#
# =============================   services    ==============================
# Earth (I3EarthModelServiceFactory)
#   DetectorDepth
#     Description :  Depth of origin of IceCube coordinate, measured from ice surface
#     Default     :  1948.0
#     Configured  :  2100.0
#
#   EarthModels
#     Description :  vector of basenames of EarthModel param file. ex. PREM_mmc.dat -> PREM_mmc suffix of the param file must be .dat
#     Default     :  []
#     Configured  :  ['PREM_pone']
#
#   IceCapSimpleAngle
#     Description :  Valid only when IceCapType is 'SimpleIceCap'. Default: 20degree from the South Pole.
#     Default     :  0.3490658503988659
#     Configured  :  None
#
#   IceCapType
#     Description :  option for choosing the shape of IceCap. If 'SimpleIceCap' is selected, it simulates spherical icecap around the SouthPole. Default is 'IceSheet', which simulates the Earth totally wrapped with a sheet of 2.8km ice.
#     Default     :  'SimpleIceCap'
#     Configured  :  'IceSheet'
#
#   MaterialModels
#     Description :  vector of basenames of MaterialRatio param file. ex. Standard.dat -> Standardsuffix of the param file must be .dat
#     Default     :  []
#     Configured  :  ['Standard']
#
#   PathToDataFileDir
#     Description :  Path to the directory containing the data files
#     Default     :  ''
#     Configured  :  ''
#
#
# =============================    modules    ==============================
# TheSource (I3InfiniteSource)
#   Prefix
#     Description :  Path to I3 file with frames to prefix to the stream (e.g. GCD information)
#     Default     :  ''
#     Configured  :  None
#
#   Stream
#     Description :  Type of frame to emit
#     Default     :  icetray.I3Frame.DAQ
#     Configured  :  icetray.I3Frame.DAQ
#
#
#
# MultiLeptonInjector_0000 (MultiLeptonInjector)
#   CylinderHeight
#     Description :  Height of the vertical cylinder around the origin within which to place events
#     Default     :  1200.0
#     Configured  :  1100.0
#
#   CylinderRadius
#     Description :  Radius of the vertical cylinder around the origin within which to place events
#     Default     :  1200.0
#     Configured  :  900.0
#
#   EarthModel
#     Description :  Name of the Earth model service to use
#     Default     :  ''
#     Configured  :  'Earth'
#
#   EndcapLength
#     Description :  Length of the fixed endcaps add to each end of the distance along which to sample interactions
#     Default     :  1200.0
#     Configured  :  1100.0
#
#   Generators
#     Description :  The collection of configurations to generate
#     Default     :  '<icecube._LeptonInjector.MultiConfigList object at 0x1481da9fcf20>'
#     Configured  :  '[<icecube._LeptonInjector.injector object at 0x1481d8283560>, <icecube._LeptonInjector.injector object at 0x1481d8283600>]'
#
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  None
#
#   InjectionRadius
#     Description :  Radius around the origin within which to target events
#     Default     :  1200.0
#     Configured  :  1100.0
#
#   MaximumAzimuth
#     Description :  Maximum azimuth angle for injected events
#     Default     :  6.283185307179586
#     Configured  :  6.283185307179586
#
#   MaximumEnergy
#     Description :  Maximum total event energy to inject
#     Default     :  1000000000.0
#     Configured  :  10000000.0
#
#   MaximumZenith
#     Description :  Maximum zenith angle for injected events
#     Default     :  3.141592653589793
#     Configured  :  3.141592653589793
#
#   MinimumAzimuth
#     Description :  Minimum azimuth angle for injected events
#     Default     :  0.0
#     Configured  :  0.0
#
#   MinimumEnergy
#     Description :  Minimum total event energy to inject
#     Default     :  10.0
#     Configured  :  100.0
#
#   MinimumZenith
#     Description :  Minimum zenith angle for injected events
#     Default     :  0.0
#     Configured  :  0.0
#
#   PowerlawIndex
#     Description :  Powerlaw index of the energy spectrum to inject (should be positive)
#     Default     :  1.0
#     Configured  :  1.5
#
#   RandomService
#     Description :  Name of the random service to use
#     Default     :  'I3RandomService'
#     Configured  :  'I3RandomService'
#
#
#
# ParticlePropagators_propagator (I3PropagatorModule)
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  None
#
#   InputMCTreeName
#     Description :  Name of the I3MCTree frame object.
#     Default     :  'I3MCTree'
#     Configured  :  'I3MCTree'
#
#   OutputMCTreeName
#     Description :  Name of the output I3MCTree frame object. If identical to the
# input or empty, the input object will be replaced.
#     Default     :  'I3MCTree'
#     Configured  :  'I3MCTree_postprop'
#
#   PropagatorServices
#     Description :  A dict mapping I3Particle::ParticleType to I3PropagatorService.
#     Default     :  None
#     Configured  :  '<icecube._sim_services.I3ParticleTypePropagatorServiceMap object at 0x1481d8283970>'
#
#   RandomService
#     Description :  A random number generator service.
#     Default     :  None
#     Configured  :  '<icecube._phys_services.I3GSLRandomService object at 0x1481d82833d0>'
#
#   RNGStateName
#     Description :  Name under which to store the state of the supplied RNG
#     Default     :  ''
#     Configured  :  'I3MCTree_RNGState'
#
#   SkipAlreadyPropagated
#     Description :  Don't re-propagate particles (experimental)
#     Default     :  False
#     Configured  :  None
#
#
#
# ParticlePropagators_add_empty_tracklist (add_empty_tracklist)
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  None
#
#   Streams
#     Description :  A list of frame types which this function should fire on.  By default runs only on physics frames
#     Default     :  [icetray.I3Frame.Physics]
#     Configured  :  [icetray.I3Frame.DAQ]
#
#
#
# get_header_0000 (get_header)
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  None
#
#   Streams
#     Description :  A list of frame types which this function should fire on.  By default runs only on physics frames
#     Default     :  [icetray.I3Frame.Physics]
#     Configured  :  [icetray.I3Frame.DAQ]
#
#
#
# I3Writer_0000 (I3Writer)
#   CompressionLevel
#     Description :  0 == default compression, 1 == best speed, 9 == best compression (6 by default)
#     Default     :  0
#     Configured  :  None
#
#   DropOrphanStreams
#     Description :  Vector of I3Frame.Stream types to drop if they are not followed by other frames. Default: drop nothing
#     Default     :  []
#     Configured  :  None
#
#   Filename
#     Description :  The file we'll write to. If it ends with .gz and no CompressionLevel is specified, it will be gzipped at gzip's default compression level.  In the I3MultiWriter this string must contain a %u printf formatting character.  (Try %04u if you're writing < 10000 files)
#     Default     :  ''
#     Configured  :  '/localscratch/cmiller.5162746.0/gen_4910.i3'
#
#   IcePickServiceKey
#     Description :  Key for an IcePick in the context that this module should check before processing physics frames.
#     Default     :  ''
#     Configured  :  None
#
#   If
#     Description :  A python function... if this returns something that evaluates to True, Module runs, else it doesn't
#     Default     :  None
#     Configured  :  None
#
#   SkipKeys
#     Description :  Don't write keys that match any of the regular expressions in this vector
#     Default     :  []
#     Configured  :  None
#
#   Streams
#     Description :  Vector of I3Frame.Stream types that we should write.  Those that do not appear here will be skipped. Default: all streams enabled.
#     Default     :  []
#     Configured  :  [icetray.I3Frame.TrayInfo, icetray.I3Frame.DAQ]
#
#
#
# ==========================================================================

# %% [markdown]
# The first frame is a **TrayInfo** frame, which stores an `I3TrayInfo` object describing how the file was produced (the IceTray “recipe”). It lists the modules that were run (e.g., injector/propagator/clsim), their configuration parameters, and which frame streams were written (e.g., TrayInfo and DAQ). It’s metadata about the processing pipeline, not the event data itself.

# %%
f = dataio.I3File(raw_file_example, "r")

daq = None
while f.more():
    frame = f.pop_frame()
    if frame.Stop == icetray.I3Frame.DAQ:
        daq = frame
        break

print("got DAQ:", daq is not None)
print("n_keys:", len(daq.keys()) if daq else None)
# Out:
# got DAQ: True
# n_keys: 7

# %%
keys = list(daq.keys())
print(keys)
# Out:
# ['MMCTrackList', 'I3Photons', 'I3MCTree_postprop', 'I3MCTree_RNGState', 'I3MCTree', 'I3EventHeader', 'EventProperties']

# %%
print(daq)
# Out:
# [ I3Frame  (DAQ):
#   'EventProperties' [DAQ] ==> LeptonInjector::BasicEventProperties (140)
#   'I3EventHeader' [DAQ] ==> I3EventHeader (99)
#   'I3MCTree' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, i3hash<I3ParticleID> > (422)
#   'I3MCTree_RNGState' [DAQ] ==> I3GSLRandomServiceState (87)
#   'I3MCTree_postprop' [DAQ] ==> TreeBase::Tree<I3Particle, I3ParticleID, i3hash<I3ParticleID> > (422)
#   'I3Photons' [DAQ] ==> I3Map<ModuleKey, I3Vector<I3CompressedPhoton> > (53)
#   'MMCTrackList' [DAQ] ==> I3Vector<I3MMCTrack> (40)
# ]

# %% [markdown]
# ## Only in the DAQ frame (raw data)
# - `I3Photons`
#
# ## Only in the Physics frame (POM Response output)
# - `EventPulseSeries`
# - `Noise_Dark`
# - `Noise_K40`
# - `PMT_Response`
# - `PMT_Response_nonoise`
# - `TriggerTime_3PMT_1DOM`
#
# ## Present in both (DAQ + Physics)
# - `EventProperties`
# - `I3EventHeader`
# - `I3MCTree`
# - `I3MCTree_RNGState`
# - `I3MCTree_postprop`
# - `MMCTrackList`

# %%
photons = daq["I3Photons"]

print("type:", type(photons))
print("n ModuleKeys:", len(photons))
# Out:
# type: <class 'icecube._simclasses.I3CompressedPhotonSeriesMap'>
# n ModuleKeys: 0

# %%
print(photons)
# Out:
# []

# %% [markdown]
# in the first DAQ frame, "I3Photons" is empty.

# %%
f = dataio.I3File(raw_file_example, "r")

n_daq = 0
n_nonempty = 0
nonempty_indices = []  # DAQ index (0-based, sadece DAQ'lar sayılıyor)

daq_idx = -1
while f.more():
    frame = f.pop_frame()
    if frame.Stop != icetray.I3Frame.DAQ:
        continue

    n_daq += 1
    daq_idx += 1

    photons = frame["I3Photons"]
    if len(photons) > 0:
        n_nonempty += 1
        nonempty_indices.append(daq_idx)

print("total DAQ frames:", n_daq)
print("DAQ frames with non-empty I3Photons:", n_nonempty)
print("non-empty DAQ indices:", nonempty_indices)
# Out:
# total DAQ frames: 200
# DAQ frames with non-empty I3Photons: 57
# non-empty DAQ indices: [6, 8, 9, 11, 17, 19, 26, 28, 29, 34, 43, 44, 47, 48, 51, 57, 60, 63, 70, 80, 82, 83, 84, 88, 90, 105, 109, 111, 119, 120, 124, 125, 126, 127, 129, 130, 133, 134, 135, 137, 140, 146, 147, 149, 158, 162, 164, 166, 167, 168, 178, 179, 180, 190, 191, 193, 199]

# %%
f = dataio.I3File(raw_file_example, "r")

frame = None
for i in range(8):  # 0..7
    frame = f.pop_frame()

print("file-frame index 6 Stop:", frame.Stop)
print("keys:", list(frame.keys()))
# Out:
# file-frame index 6 Stop: DAQ
# keys: ['MMCTrackList', 'I3Photons', 'I3MCTree_postprop', 'I3MCTree_RNGState', 'I3MCTree', 'I3EventHeader', 'EventProperties']

# %%
# print(frame['I3Photons'])

# %%
frame['I3Photons'][dataclasses.ModuleKey(231, 18)]

# %%
print(frame['I3Photons'][dataclasses.ModuleKey(231, 18)])
# Out:
# [[I3CompressedPhoton:
#         Time: 968.141
#       Weight: 1
#   Wavelength: 4.50997e-07
#       Zenith: 2.09724
#      Azimuth: 1.79005
#     Position: (-0.0376072,0.198429,0.0760731)
#   Group Vel.: 0.21702
#   ParticleID: 10320399505715655872,133)]]

# %%
len(frame['I3Photons'][dataclasses.ModuleKey(231, 18)])
# Out:
# 1

# %%
print(frame['I3Photons'][dataclasses.ModuleKey(247, 16)])
# Out:
# [[I3CompressedPhoton:
#         Time: 488.207
#       Weight: 1
#   Wavelength: 4.41561e-07
#       Zenith: 1.60039
#      Azimuth: 1.05431
#     Position: (0.0523264,0.205239,-0.0417951)
#   Group Vel.: 0.216693
#   ParticleID: 10320399505715655872,133)], [I3CompressedPhoton:
#         Time: 553.593
#       Weight: 1
#   Wavelength: 4.70742e-07
#       Zenith: 1.1452
#      Azimuth: 1.26438
#     Position: (0.0464862,0.113896,0.177392)
#   Group Vel.: 0.217627
#   ParticleID: 10320399505715655872,133)], [I3CompressedPhoton:
#         Time: 489.622
#       Weight: 1
#   Wavelength: 4.47005e-07
#       Zenith: 1.58093
#      Azimuth: 1.08256
#     Position: (-0.00426921,0.138696,-0.165342)
#   Group Vel.: 0.216885
#   ParticleID: 10320399505715655872,133)], [I3CompressedPhoton:
#         Time: 503.867
#       Weight: 1
#   Wavelength: 4.46369e-07
#       Zenith: 1.56747
#      Azimuth: 1.10571
#     Position: (0.0123699,0.182144,0.114782)
#   Group Vel.: 0.216863
#   ParticleID: 10320399505715655872,133)], [I3CompressedPhoton:
#         Time: 513.528
#       Weight: 1
#   Wavelength: 4.54404e-07
#       Zenith: 1.58001
#      Azimuth: 1.11311
#     Position: (0.0495822,0.208789,-0.0235713)
#   Group Vel.: 0.217132
#   ParticleID: 10320399505715655872,133)]]

# %%
len(frame['I3Photons'][dataclasses.ModuleKey(247, 16)])
# Out:
# 5

# %%
# ModuleKey neydi, string ve OM miydi

# %% [markdown]
# From the Confluence page, the DOM radius is listed as **DOMRadius = 0.21590 m**.
#
# To sanity-check what the `Position (x, y, z)` field in `I3CompressedPhoton`, I computed $ r = \sqrt{x^2 + y^2 + z^2} $ for three example photons (from the outputs of the cells 22, 22 above). The resulting radii were:
#
# - 0.2158135
# - 0.2158887
# - 0.2158731
#
# These values are all very close to 0.21590 m, which strongly suggests that the `(x, y, z)` coordinates are given in the DOM’s local coordinate system (origin near the DOM center) and that `Position` corresponds to the point where the photon intersects/enters the DOM surface.

# %%
# neden bazi I3Photonlar bos?

# %%
mk = dataclasses.ModuleKey(247, 16)
ts = [p.time for p in frame["I3Photons"][mk]]  # p is I3CompressedPhoton
ts
# Out:
# [488.2065734863281,
#  553.592529296875,
#  489.6219482421875,
#  503.8673095703125,
#  513.5278930664062]

# %%
hdr = frame["I3EventHeader"]
hdr.start_time if hasattr(hdr, "start_time") else hdr
# Out:
# I3Time(   0,                 0L)

# %%
mctree = frame["I3MCTree_postprop"]  # veya "I3MCTree"

# %%
print(mctree.primaries)
# Out:
# [[ I3Particle MajorID : 10320399505715655872
#              MinorID : 136
#               Zenith : 2.41197
#              Azimuth : 5.61741
#                    X : -589.976
#                    Y : 399.972
#                    Z : 296.257
#                 Time : 0
#               Energy : 993.477
#                Speed : 0.299792
#               Length : 0
#                 Type : NuMu
#         PDG encoding : 14
#                Shape : Primary
#               Status : NotSet
#             Location : Anywhere
# ]]

# %%
prim = mctree.primaries[0]

# %%
prim.time, prim.pos
# Out:
# (0.0, I3Position(-589.976,399.972,296.257))

# %%
type(frame["I3Photons"])
# Out:
# icecube._simclasses.I3CompressedPhotonSeriesMap

# %%
photons_map = frame["I3Photons"]  # I3CompressedPhotonSeriesMap

# map'ten bir key al (ilk ModuleKey)
mk = next(iter(photons_map.keys()))
mk
# Out:
# ModuleKey(231,18)

# %%
# o DOM/module için photon listesi
series = photons_map[mk]

# %%
print("map type:", type(photons_map))
print("key type:", type(mk))
print("series type:", type(series))
print("n photons in series:", len(series))

if len(series) > 0:
    print("first photon type:", type(series[0]))
# Out:
# map type: <class 'icecube._simclasses.I3CompressedPhotonSeriesMap'>
# key type: <class 'icecube._dataclasses.ModuleKey'>
# series type: <class 'icecube._simclasses.I3CompressedPhotonSeries'>
# n photons in series: 1
# first photon type: <class 'icecube._simclasses.I3CompressedPhoton'>

# %%
mk = dataclasses.ModuleKey(231, 18)

# %%
print(frame['I3Photons'][dataclasses.ModuleKey(231, 18)][0])
# Out:
# [I3CompressedPhoton:
#         Time: 968.141
#       Weight: 1
#   Wavelength: 4.50997e-07
#       Zenith: 2.09724
#      Azimuth: 1.79005
#     Position: (-0.0376072,0.198429,0.0760731)
#   Group Vel.: 0.21702
#   ParticleID: 10320399505715655872,133)]

# %%
print(type(frame['I3Photons'][dataclasses.ModuleKey(231, 18)][0]))
# Out:
# <class 'icecube._simclasses.I3CompressedPhoton'>

# %%
print(type(frame['I3Photons'][dataclasses.ModuleKey(231, 18)]))
# Out:
# <class 'icecube._simclasses.I3CompressedPhotonSeries'>

# %%
########

# %%
mctree = frame["I3MCTree"]
prim = list(mctree.primaries)[0]
print("Primary time:", prim.time, "ns")
print("Primary pos :", prim.pos)
# Out:
# Primary time: 0.0 ns
# Primary pos : I3Position(-589.976,399.972,296.257)

# %%
from icecube import dataclasses

key = dataclasses.ModuleKey(231, 18)
ph = frame["I3Photons"][key][0]

# %%
print(ph)
# Out:
# [I3CompressedPhoton:
#         Time: 968.141
#       Weight: 1
#   Wavelength: 4.50997e-07
#       Zenith: 2.09724
#      Azimuth: 1.79005
#     Position: (-0.0376072,0.198429,0.0760731)
#   Group Vel.: 0.21702
#   ParticleID: 10320399505715655872,133)]

# %%
ph.particleMajorID
# Out:
# 10320399505715655872

# %%
ph.particleMinorID
# Out:
# 133

# %%
from icecube import dataclasses

key = dataclasses.ModuleKey(231,18)
ph = frame["I3Photons"][key][0]
maj, minr = ph.particleMajorID, ph.particleMinorID

def find_in_tree(tree):
    for p in tree:
        if p.id.majorID == maj and p.id.minorID == minr:
            return p
    return None

p1 = find_in_tree(frame["I3MCTree"])
p2 = find_in_tree(frame["I3MCTree_postprop"])

print("In I3MCTree        :", p1 is not None)
print("In I3MCTree_PostProp:", p2 is not None)
print("p1:", p1)
print("p2:", p2)
# Out:
# In I3MCTree        : True
# In I3MCTree_PostProp: True
# p1: [ I3Particle MajorID : 10320399505715655872
#              MinorID : 133
#               Zenith : 2.4186
#              Azimuth : 5.63293
#                    X : -589.976
#                    Y : 399.972
#                    Z : 296.257
#                 Time : 0
#               Energy : 814.357
#                Speed : 0.299792
#               Length : nan
#                 Type : Hadrons
#         PDG encoding : -2000001006
#                Shape : Cascade
#               Status : NotSet
#             Location : InIce
# ]
# p2: [ I3Particle MajorID : 10320399505715655872
#              MinorID : 133
#               Zenith : 2.4186
#              Azimuth : 5.63293
#                    X : -589.976
#                    Y : 399.972
#                    Z : 296.257
#                 Time : 0
#               Energy : 814.357
#                Speed : 0.299792
#               Length : nan
#                 Type : Hadrons
#         PDG encoding : -2000001006
#                Shape : Cascade
#               Status : NotSet
#             Location : InIce
# ]

# %%
from icecube import dataio, simclasses
from collections import Counter

def photon_map_keys(frame):
    """Frame'deki tüm I3CompressedPhotonSeriesMap key'lerini döndür."""
    keys = []
    for k in frame.keys():
        try:
            v = frame[k]
        except Exception:
            continue
        if isinstance(v, simclasses.I3CompressedPhotonSeriesMap):
            keys.append(k)
    return keys

def pick_tree(frame, prefer_postprop=True):
    """
    Photon ParticleID'lerinin refer ettiği en olası MCTree'yi seç.
    Bu dosyada PostProp key'i: 'I3MCTree_postprop'
    """
    candidates = []
    if prefer_postprop:
        candidates.append("I3MCTree_postprop")
    candidates.append("I3MCTree")

    for k in candidates:
        if k in frame:
            return frame[k], k
    return None, None

def src_class(p):
    """Kaynak parçacığı kaba sınıflandır."""
    if p is None:
        return "UNKNOWN"

    t = str(p.type)
    s = str(p.shape)

    if "Mu" in t:
        return "MUON"

    # muon propagation boyunca doğan secondary/loss parçacıklar çoğunlukla time>0 olur
    if getattr(p, "time", 0) > 0:
        return "SRC_TIME>0"

    if "Track" in s:
        return "TRACK"
    if "Cascade" in s or "Hadrons" in t:
        return "CASCADE"

    return "OTHER"

def scan_frame(frame, prefer_postprop=True):
    """Tek bir frame'de photonları tarar; photon map yoksa None döner."""
    pkeys = photon_map_keys(frame)
    if not pkeys:
        return None

    tree, treekey = pick_tree(frame, prefer_postprop=prefer_postprop)
    if tree is None:
        return None

    # hızlı lookup
    lut = {(p.id.majorID, p.id.minorID): p for p in tree}

    total = 0
    muon_ph = 0
    timegt0_ph = 0
    counts = Counter()

    for pk in pkeys:
        photmap = frame[pk]
        for omkey, series in photmap.items():
            for ph in series:
                total += 1
                p = lut.get((ph.particleMajorID, ph.particleMinorID), None)

                cls = src_class(p)
                counts[cls] += 1

                if cls == "MUON":
                    muon_ph += 1
                if p is not None and getattr(p, "time", 0) > 0:
                    timegt0_ph += 1

    hdr = frame["I3EventHeader"] if "I3EventHeader" in frame else None
    tag = {
        "stop": str(frame.Stop),
        "run": getattr(hdr, "run_id", None),
        "event": getattr(hdr, "event_id", None),
        "subevent": getattr(hdr, "sub_event_id", None),
    }

    return {
        "tag": tag,
        "tree": treekey,
        "photon_keys": pkeys,
        "total": total,
        "muon_ph": muon_ph,
        "timegt0_ph": timegt0_ph,
        "counts": counts,
    }

def scan_file(path, max_frames=None, prefer_postprop=True):
    """
    Dosyadaki tüm frame'leri (DAQ dahil) gezer, photon map olanları toplar.
    """
    f = dataio.I3File(path)

    agg = Counter()
    frames_with_photons = []
    n = 0

    while f.more():
        fr = f.pop_frame()
        n += 1
        if max_frames is not None and n > max_frames:
            break

        res = scan_frame(fr, prefer_postprop=prefer_postprop)
        if res is None:
            continue

        agg.update(res["counts"])
        frames_with_photons.append(res)

    print("Frames scanned:", n)
    print("Frames with photon maps:", len(frames_with_photons))
    print("Aggregate photon source classes:", dict(agg))

    mu_frames = [r for r in frames_with_photons if r["muon_ph"] > 0]
    t0_frames = [r for r in frames_with_photons if r["timegt0_ph"] > 0]

    print("Frames with MUON-tagged photons:", len(mu_frames))
    print("Frames with any src.time>0 photons:", len(t0_frames))

    mu_frames.sort(key=lambda r: r["muon_ph"], reverse=True)
    print("\nTop frames by MUON photons:")
    for r in mu_frames[:10]:
        print(r["tag"], "muon_ph=", r["muon_ph"], "total=", r["total"],
              "tree=", r["tree"], "pkeys=", r["photon_keys"])

    t0_frames.sort(key=lambda r: r["timegt0_ph"], reverse=True)
    print("\nTop frames by src.time>0 photons (muon-prop/loss candidate):")
    for r in t0_frames[:10]:
        print(r["tag"], "time>0_ph=", r["timegt0_ph"], "total=", r["total"],
              "tree=", r["tree"], "pkeys=", r["photon_keys"])

    return frames_with_photons, agg

# %%
frames_with_photons, agg = scan_file(raw_file_example, max_frames=None, prefer_postprop=True)
# Out:
# Frames scanned: 201
# Frames with photon maps: 200
# Aggregate photon source classes: {'CASCADE': 45217890, 'MUON': 173748, 'SRC_TIME>0': 5230261}
# Frames with MUON-tagged photons: 50
# Frames with any src.time>0 photons: 52
#
# Top frames by MUON photons:
# {'stop': 'DAQ', 'run': 4910, 'event': 64, 'subevent': 0} muon_ph= 20701 total= 36841 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 35, 'subevent': 0} muon_ph= 12629 total= 380890 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 168, 'subevent': 0} muon_ph= 12440 total= 131538 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 120, 'subevent': 0} muon_ph= 11663 total= 12273 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 20, 'subevent': 0} muon_ph= 11312 total= 24183 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 141, 'subevent': 0} muon_ph= 9193 total= 9348 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 130, 'subevent': 0} muon_ph= 8379 total= 4525501 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 125, 'subevent': 0} muon_ph= 7685 total= 7921 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 84, 'subevent': 0} muon_ph= 7543 total= 11775 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 85, 'subevent': 0} muon_ph= 7279 total= 12306 tree= I3MCTree_postprop pkeys= ['I3Photons']
#
# Top frames by src.time>0 photons (muon-prop/loss candidate):
# {'stop': 'DAQ', 'run': 4910, 'event': 130, 'subevent': 0} time>0_ph= 4525501 total= 4525501 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 35, 'subevent': 0} time>0_ph= 380890 total= 380890 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 179, 'subevent': 0} time>0_ph= 135347 total= 45313135 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 168, 'subevent': 0} time>0_ph= 131382 total= 131538 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 64, 'subevent': 0} time>0_ph= 36751 total= 36841 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 20, 'subevent': 0} time>0_ph= 24183 total= 24183 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 83, 'subevent': 0} time>0_ph= 18882 total= 18882 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 150, 'subevent': 0} time>0_ph= 17605 total= 17605 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 45, 'subevent': 0} time>0_ph= 12566 total= 12566 tree= I3MCTree_postprop pkeys= ['I3Photons']
# {'stop': 'DAQ', 'run': 4910, 'event': 85, 'subevent': 0} time>0_ph= 12306 total= 12306 tree= I3MCTree_postprop pkeys= ['I3Photons']

# %%
import pandas as pd
from icecube import dataio, simclasses

def _find_photon_map_keys(frame):
    keys = []
    for k in frame.keys():
        try:
            v = frame[k]
        except Exception:
            continue
        if isinstance(v, simclasses.I3CompressedPhotonSeriesMap):
            keys.append(k)
    return keys

def _find_iterable_mctree_keys(frame):
    """
    Frame'de 'MCTree' geçen ama iterable olmayan (örn RNGState) objeleri dışarıda bırakır.
    """
    out = []
    for k in frame.keys():
        if "MCTree" not in k:
            continue
        try:
            obj = frame[k]
        except Exception:
            continue
        try:
            iter(obj)  # iterable mı?
            out.append(k)
        except TypeError:
            continue
    return out

def _build_pid_lookup_for_trees(frame, tree_keys):
    """
    tree_key -> {(major, minor): I3Particle}
    """
    lut_by_tree = {}
    for tk in tree_keys:
        tree = frame[tk]
        lut = {}
        for p in tree:
            lut[(int(p.id.majorID), int(p.id.minorID))] = p
        lut_by_tree[tk] = lut
    return lut_by_tree

def photons_to_dataframe(
    path: str,
    *,
    only_daq: bool = True,
    max_frames: int | None = None,
    max_daq_frames: int | None = None,
    max_rows: int | None = 200_000,
):
    f = dataio.I3File(path)

    rows = []
    file_frame_index = 0
    daq_index = 0

    while f.more():
        fr = f.pop_frame()
        file_frame_index += 1

        stop_name = str(fr.Stop)
        if only_daq and stop_name != "DAQ":
            continue

        if stop_name == "DAQ":
            daq_index += 1
            if max_daq_frames is not None and daq_index > max_daq_frames:
                break

        if max_frames is not None and file_frame_index > max_frames:
            break

        photon_keys = _find_photon_map_keys(fr)
        if not photon_keys:
            continue

        tree_keys = _find_iterable_mctree_keys(fr)
        lut_by_tree = _build_pid_lookup_for_trees(fr, tree_keys)

        hdr = fr["I3EventHeader"] if "I3EventHeader" in fr else None
        run_id = getattr(hdr, "run_id", None)
        event_id = getattr(hdr, "event_id", None)
        subevent_id = getattr(hdr, "sub_event_id", None)

        for pk in photon_keys:
            photmap = fr[pk]

            for omkey, series in photmap.items():
                # ModuleKey parse
                try:
                    s = int(omkey.string)
                    om = int(omkey.om)
                except Exception:
                    s = None
                    om = None

                for i_ph, ph in enumerate(series):
                    pid = (int(ph.particleMajorID), int(ph.particleMinorID))

                    found_trees = []
                    particle_str_by_tree = {}
                    sig_parts = []

                    for tk in tree_keys:
                        lut = lut_by_tree[tk]          # <-- FIX: tree’ye ait lut
                        if pid in lut:
                            found_trees.append(tk)
                            particle_str_by_tree[tk] = str(lut[pid])  # <-- FIX
                            sig_parts.append(f"{tk}:1")
                        else:
                            sig_parts.append(f"{tk}:0")

                    presence_signature = "|".join(sig_parts) if sig_parts else ""
                    if len(found_trees) == 0:
                        presence_case = "none"
                    elif len(found_trees) == 1:
                        presence_case = f"only:{found_trees[0]}"
                    else:
                        presence_case = "multiple"

                    # photon position (DOM-local olabilir)
                    try:
                        posx, posy, posz = float(ph.pos.x), float(ph.pos.y), float(ph.pos.z)
                    except Exception:
                        posx = posy = posz = None

                    rows.append({
                        "file_frame_index": file_frame_index,
                        "daq_index": daq_index if stop_name == "DAQ" else None,
                        "stop": stop_name,
                        "run_id": run_id,
                        "event_id": event_id,
                        "sub_event_id": subevent_id,

                        "photon_map_key": pk,

                        "modulekey": str(omkey),
                        "string": s,
                        "om": om,
                        "photon_index": i_ph,

                        "photon_time": float(ph.time),
                        "photon_weight": float(ph.weight),
                        "photon_wavelength": float(ph.wavelength),
                        "photon_zenith": float(ph.zenith),
                        "photon_azimuth": float(ph.azimuth),
                        "photon_group_velocity": float(ph.groupVelocity),
                        "photon_pos_x": posx,
                        "photon_pos_y": posy,
                        "photon_pos_z": posz,

                        "pid_major": pid[0],
                        "pid_minor": pid[1],

                        "mctree_keys_in_frame": list(tree_keys),
                        "pid_found_in_trees": list(found_trees),
                        "pid_presence_signature": presence_signature,
                        "pid_presence_case": presence_case,
                        "particle_str_by_tree": particle_str_by_tree,
                    })

                    if max_rows is not None and len(rows) >= max_rows:
                        return pd.DataFrame(rows)

    return pd.DataFrame(rows)

# %%
df = photons_to_dataframe(raw_file_example, max_rows=50_000) 
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df = photons_to_dataframe(raw_file_example, max_rows=50_000)
#       2 df.head()
#
# Cell In[51], line 149, in photons_to_dataframe(path, only_daq, max_frames, max_daq_frames, max_rows)
#     128 except Exception:
#     129     posx = posy = posz = None
#     131 rows.append({
#     132     "file_frame_index": file_frame_index,
#     133     "daq_index": daq_index if stop_name == "DAQ" else None,
#     134     "stop": stop_name,
#     135     "run_id": run_id,
#     136     "event_id": event_id,
#     137     "sub_event_id": subevent_id,
#     138
#     139     "photon_map_key": pk,
#     140
#     141     "modulekey": str(omkey),
#     142     "string": s,
#     143     "om": om,
#     144     "photon_index": i_ph,
#     145
#     146     "photon_time": float(ph.time),
#     147     "photon_weight": float(ph.weight),
#     148     "photon_wavelength": float(ph.wavelength),
# --> 149     "photon_zenith": float(ph.zenith),
#     150     "photon_azimuth": float(ph.azimuth),
#     151     "photon_group_velocity": float(ph.groupVelocity),
#     152     "photon_pos_x": posx,
#     153     "photon_pos_y": posy,
#     154     "photon_pos_z": posz,
#     155
#     156     "pid_major": pid[0],
#     157     "pid_minor": pid[1],
#     158
#     159     "mctree_keys_in_frame": list(tree_keys),
#     160     "pid_found_in_trees": list(found_trees),
#     161     "pid_presence_signature": presence_signature,
#     162     "pid_presence_case": presence_case,
#     163     "particle_str_by_tree": particle_str_by_tree,
#     164 })
#     166 if max_rows is not None and len(rows) >= max_rows:
#     167     return pd.DataFrame(rows)
#
# AttributeError: 'I3CompressedPhoton' object has no attribute 'zenith'
